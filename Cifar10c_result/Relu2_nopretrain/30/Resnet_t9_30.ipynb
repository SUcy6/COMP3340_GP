# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.nn.init as init
from torch.nn.parameter import Parameter
from torchvision import datasets, transforms
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import StepLR
import torchvision
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#!pip install medpy
#!pip install torchio

# %%
# Use CIFAR-10 dataset for training and CIFAR-10-C dataset for testing
# Get CIFAR-10 dataset
train_dataset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
]))

# Get CIFAR-10-C dataset which includes diffrent types of corruptions
#!wget https://zenodo.org/record/2535967/files/CIFAR-10-C.tar
#!tar -xvf CIFAR-10-C.tar
# Out:
# Files already downloaded and verified

# %%
# Split the dataset into training, validation
train_size = int(0.8 * len(train_dataset))
val_size = int(0.2 * len(train_dataset))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 2
#       1 # Split the dataset into training, validation
# ----> 2 train_size = int(0.8 * len(train_dataset))
#       3 val_size = int(0.2 * len(train_dataset))
#
# NameError: name 'train_dataset' is not defined

# %%
# Define the function to get the test data in .npy format
def get_test_data(data_name):
    test_data = np.load("./CIFAR-10-C/" + data_name + ".npy")
    test_label = np.load("./CIFAR-10-C/" + "labels.npy")
    test_data = test_data.astype('float32')
    test_data = test_data / 255.0
    # Reshape test data from (50000, 32, 32, 3) to (50000, 3, 32, 32)
    test_data = np.transpose(test_data, (0, 3, 1, 2))
    # Standardize the data with mean = (0.4914, 0.4822, 0.4465), var = (0.2023, 0.1994, 0.2010)
    test_data[:, 0, :, :] = (test_data[:, 0, :, :] - 0.4914) / 0.2023
    test_data[:, 1, :, :] = (test_data[:, 1, :, :] - 0.4822) / 0.1994
    test_data[:, 2, :, :] = (test_data[:, 2, :, :] - 0.4465) / 0.2010
    test_data = torch.from_numpy(test_data)
    test_label = torch.from_numpy(test_label)
    test_dataset = torch.utils.data.TensorDataset(test_data, test_label)
    return test_dataset

# %%
# Define the device
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
#device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# mps

# %%
class LP_ReLU2(nn.Module):
    
    def __init__(self, in_features, alpha = None, beta = None):
        '''
        Initialization.
        INPUT:
            - in_features: shape of the input
            - aplha: trainable parameter
            aplha is initialized with zero value by default
        '''
        super(LP_ReLU2,self).__init__()
        self.in_features = in_features

        # initialize alpha
        if alpha == None:
            self.alpha = Parameter(torch.tensor(5.0)) # create a tensor out of alpha
        else:
            self.alpha = Parameter(torch.tensor(alpha)) # create a tensor out of alpha
        if beta == None:
            self.beta = Parameter(torch.tensor(8.1)) 
        else:
            self.beta = Parameter(torch.tensor(beta))

        self.alpha.requiresGrad = True # set requiresGrad to true!
        self.beta.requiresGrad = True

    def forward(self, x):
        '''
        Forward pass of the function.
        Applies the function to the input elementwise.
        '''
        
        threshold0 = torch.zeros(x.shape)
        threshold0 = threshold0.to(device)
        x1 = torch.where(x < threshold0, threshold0, x)
        
        threshold1 = torch.ones(x1.shape)
        threshold1 = threshold1.to(device)
        threshold1 = threshold1 * (self.alpha)
        x2 = torch.where(x1 < threshold1, x1, threshold1)

        threshold2 = torch.ones(x2.shape)
        threshold2 = threshold2.to(device)
        threshold2 = threshold2 * (self.alpha)
        threshold2 = threshold2.to(device)
        x3 = torch.where(x2 > threshold2, 0.05*(x2-threshold2)+threshold2, x2)

        threshold3 = torch.ones(x3.shape)
        threshold3 = threshold3.to(device)
        threshold3 = threshold3 * (self.beta)
        f3 = 0.05*(x3-threshold2)+threshold2
        max_val = torch.max(f3)
        x4 = torch.where(x3 > threshold3, max_val + (0.05/3)*(x3-max_val), x3)

        return x4
    
# Build the ResNet50 model
def get_model(pretrain):
    if pretrain == 1:
        model = torchvision.models.resnet50(weights='ResNet50_Weights.IMAGENET1K_V1')
    else:
        model = torchvision.models.resnet50(weights=None)
    model.classifier = nn.Sequential(
        nn.Linear(2048, 1024),
        LP_ReLU2(1024),
        nn.Linear(1024, 10),
    )

    # change activation function
    model.relu = LP_ReLU2(64)
    model.layer1[0].relu = LP_ReLU2(256)
    model.layer1[1].relu = LP_ReLU2(256)
    model.layer1[2].relu = LP_ReLU2(256)

    model.layer2[0].relu = LP_ReLU2(512)
    model.layer2[1].relu = LP_ReLU2(512)
    model.layer2[2].relu = LP_ReLU2(512)
    model.layer2[3].relu = LP_ReLU2(512)

    model.layer3[0].relu = LP_ReLU2(1024)
    model.layer3[1].relu = LP_ReLU2(1024)
    model.layer3[2].relu = LP_ReLU2(1024)
    model.layer3[3].relu = LP_ReLU2(1024)
    model.layer3[4].relu = LP_ReLU2(1024)
    model.layer3[5].relu = LP_ReLU2(1024)

    model.layer4[0].relu = LP_ReLU2(2048)
    model.layer4[1].relu = LP_ReLU2(2048)
    model.layer4[2].relu = LP_ReLU2(2048)

    return model

# %%
# Define the training function and return loss
def train(model, device, train_loader, optimizer, epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.cross_entropy(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 10000 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))
        
        if epoch == 30:
            #store the model parameters and output the model
            torch.save(model.state_dict(), './relu2result/model_parameters_' + str(epoch) + '_np.pt')
    return loss.item()

# Define the validation function and return loss
def validate(model, device, valid_loader):
    model.eval()
    valid_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in valid_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            valid_loss += F.cross_entropy(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    valid_loss /= len(valid_loader.dataset)
    print('Validation set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)'.format(
        valid_loss, correct, len(valid_loader.dataset),
        100. * correct / len(valid_loader.dataset)))
    return valid_loss

# Define the testing function and return accuracy
def test(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.cross_entropy(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    print('Test set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return correct / len(test_loader.dataset), test_loss

# %%
# Define the optimizer
def get_optimizer(model, lr):
    optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=0.9)
    return optimizer

# Define the training process
def train_process(model, device, train_loader, valid_loader, optimizer, epochs):
    train_losses = []
    valid_losses = []
    for epoch in range(1, epochs + 1):
        train_losses.append(train(model, device, train_loader, optimizer, epoch))
        valid_losses.append(validate(model, device, valid_loader))
    return train_losses, valid_losses

# Define the testing process
def test_process(model, device, test_loader):
    test_acc = test(model, device, test_loader)
    return test_acc

# %%
# Set the batch size used for model training
batch_size = 16
# Define the names for data
data_names = ['brightness', 'contrast', 'defocus_blur', 'elastic_transform', 'fog', 'frost', 'gaussian_blur', 'gaussian_noise', 'glass_blur',
                'impulse_noise', 'jpeg_compression', 'motion_blur', 'pixelate', 'saturate', 'shot_noise', 'snow', 'spatter', 'speckle_noise',
                'zoom_blur']

# %%
train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [train_size, val_size])

# %%
# Empty the GPU memory
torch.cuda.empty_cache()

# Start training and testing with batchsize = 16 and learning rate = 0.001 and leaky_relu
fig, axs = plt.subplots(2, 1, figsize=(10, 10))
learnR = 0.001
test_accs = []
i = 0
model = get_model(0)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
model = model.to(device)
optimizer = get_optimizer(model, learnR)
train_losses, valid_losses = train_process(model, device, train_loader, val_loader, optimizer, 60)

# Plot the training loss given batch size = 16 and learning rate = 0.001 and leaky_relu
axs[0].plot(train_losses)
axs[0].set_title('Training loss, given batch_size=16, learning_rate=0.001, leaky_relu')
axs[0].set_xlabel('Epochs')
axs[0].set_ylabel('Loss')

# Plot the validation loss given batch size = 16 and learning rate = 0.001 and leaky_relu
axs[1].plot(valid_losses)
axs[1].set_title('Validation loss, given batch_size=16, learning_rate=0.001, leaky_relu')
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Loss')

# Change the train_losses, valid_losses, test_losses, test_accs as different pandas dataframes
train_lossespd = pd.DataFrame(train_losses)
valid_lossespd = pd.DataFrame(valid_losses)

# Save the dataframes as csv files
train_lossespd.to_csv('./relu2result/train_losses_np.csv')
valid_lossespd.to_csv('./relu2result/valid_losses_np.csv')
# Out:
# Train Epoch: 1 [0/40000 (0%)]	Loss: 6.993261
# Validation set: Average loss: 2.0121, Accuracy: 3506/10000 (35%)
# Train Epoch: 2 [0/40000 (0%)]	Loss: 2.708211
# Validation set: Average loss: 1.6779, Accuracy: 4369/10000 (44%)
# Train Epoch: 3 [0/40000 (0%)]	Loss: 2.060824
# Validation set: Average loss: 1.4740, Accuracy: 4804/10000 (48%)
# Train Epoch: 4 [0/40000 (0%)]	Loss: 1.421020
# Validation set: Average loss: 1.4479, Accuracy: 4861/10000 (49%)
# Train Epoch: 5 [0/40000 (0%)]	Loss: 1.918852
# Validation set: Average loss: 1.4487, Accuracy: 4910/10000 (49%)
# Train Epoch: 6 [0/40000 (0%)]	Loss: 1.577391
# Validation set: Average loss: 1.3462, Accuracy: 5159/10000 (52%)
# Train Epoch: 7 [0/40000 (0%)]	Loss: 1.106039
# Validation set: Average loss: 1.2772, Accuracy: 5499/10000 (55%)
# Train Epoch: 8 [0/40000 (0%)]	Loss: 1.190657
# Validation set: Average loss: 1.3486, Accuracy: 5175/10000 (52%)
# Train Epoch: 9 [0/40000 (0%)]	Loss: 1.211269
# Validation set: Average loss: 1.3216, Accuracy: 5436/10000 (54%)
# Train Epoch: 10 [0/40000 (0%)]	Loss: 1.293779
# Validation set: Average loss: 1.2094, Accuracy: 5644/10000 (56%)
# Train Epoch: 11 [0/40000 (0%)]	Loss: 1.120641
# Validation set: Average loss: 1.1920, Accuracy: 5796/10000 (58%)
# Train Epoch: 12 [0/40000 (0%)]	Loss: 1.029866
# Validation set: Average loss: 1.1769, Accuracy: 5861/10000 (59%)
# Train Epoch: 13 [0/40000 (0%)]	Loss: 0.700273
# Validation set: Average loss: 1.2471, Accuracy: 5597/10000 (56%)
# Train Epoch: 14 [0/40000 (0%)]	Loss: 0.445200
# Validation set: Average loss: 1.1674, Accuracy: 5940/10000 (59%)
# Train Epoch: 15 [0/40000 (0%)]	Loss: 0.940517
# Validation set: Average loss: 1.1778, Accuracy: 5994/10000 (60%)
# Train Epoch: 16 [0/40000 (0%)]	Loss: 0.888058
# Validation set: Average loss: 1.1922, Accuracy: 5974/10000 (60%)
# Train Epoch: 17 [0/40000 (0%)]	Loss: 1.304492
# Validation set: Average loss: 1.1215, Accuracy: 6179/10000 (62%)
# Train Epoch: 18 [0/40000 (0%)]	Loss: 0.815276
# Validation set: Average loss: 1.1009, Accuracy: 6255/10000 (63%)
# Train Epoch: 19 [0/40000 (0%)]	Loss: 0.489075
# Validation set: Average loss: 1.1613, Accuracy: 6178/10000 (62%)
# Train Epoch: 20 [0/40000 (0%)]	Loss: 0.770809
# Validation set: Average loss: 1.1399, Accuracy: 6109/10000 (61%)
# Train Epoch: 21 [0/40000 (0%)]	Loss: 0.979762
# Validation set: Average loss: 1.1081, Accuracy: 6326/10000 (63%)
# Train Epoch: 22 [0/40000 (0%)]	Loss: 0.785538
# Validation set: Average loss: 1.1484, Accuracy: 6340/10000 (63%)
# Train Epoch: 23 [0/40000 (0%)]	Loss: 0.551402
# Validation set: Average loss: 1.1947, Accuracy: 6375/10000 (64%)
# Train Epoch: 24 [0/40000 (0%)]	Loss: 0.532637
# Validation set: Average loss: 1.1742, Accuracy: 6391/10000 (64%)
# Train Epoch: 25 [0/40000 (0%)]	Loss: 0.126856
# Validation set: Average loss: 1.2028, Accuracy: 6345/10000 (63%)
# Train Epoch: 26 [0/40000 (0%)]	Loss: 0.131783
# Validation set: Average loss: 1.2952, Accuracy: 6416/10000 (64%)
# Train Epoch: 27 [0/40000 (0%)]	Loss: 0.120104
# Validation set: Average loss: 1.2915, Accuracy: 6572/10000 (66%)
# Train Epoch: 28 [0/40000 (0%)]	Loss: 0.184234
# Validation set: Average loss: 1.4894, Accuracy: 6254/10000 (63%)
# Train Epoch: 29 [0/40000 (0%)]	Loss: 0.134699
# Validation set: Average loss: 1.4322, Accuracy: 6381/10000 (64%)
# Train Epoch: 30 [0/40000 (0%)]	Loss: 0.307448
# Validation set: Average loss: 1.3374, Accuracy: 6469/10000 (65%)
# Train Epoch: 31 [0/40000 (0%)]	Loss: 0.487760
# Validation set: Average loss: 1.5265, Accuracy: 6298/10000 (63%)
# Train Epoch: 32 [0/40000 (0%)]	Loss: 0.027312
# Validation set: Average loss: 1.4036, Accuracy: 6425/10000 (64%)
# Train Epoch: 33 [0/40000 (0%)]	Loss: 0.051384
# Validation set: Average loss: 1.4583, Accuracy: 6177/10000 (62%)
# Train Epoch: 34 [0/40000 (0%)]	Loss: 0.373912
# Validation set: Average loss: 1.4734, Accuracy: 6442/10000 (64%)
# Train Epoch: 35 [0/40000 (0%)]	Loss: 0.327072
# Validation set: Average loss: 1.5781, Accuracy: 6449/10000 (64%)
# Train Epoch: 36 [0/40000 (0%)]	Loss: 0.064791
# Validation set: Average loss: 1.5947, Accuracy: 6542/10000 (65%)
# Train Epoch: 37 [0/40000 (0%)]	Loss: 0.078568
# Validation set: Average loss: 1.6844, Accuracy: 6334/10000 (63%)
# Train Epoch: 38 [0/40000 (0%)]	Loss: 0.077275
# Validation set: Average loss: 1.6064, Accuracy: 6567/10000 (66%)
# Train Epoch: 39 [0/40000 (0%)]	Loss: 0.149591
# Validation set: Average loss: 1.6162, Accuracy: 6490/10000 (65%)
# Train Epoch: 40 [0/40000 (0%)]	Loss: 0.011870
# Validation set: Average loss: 1.6782, Accuracy: 6553/10000 (66%)
# Train Epoch: 41 [0/40000 (0%)]	Loss: 0.005093
# Validation set: Average loss: 1.7327, Accuracy: 6503/10000 (65%)
# Train Epoch: 42 [0/40000 (0%)]	Loss: 0.046854
# Validation set: Average loss: 1.7319, Accuracy: 6642/10000 (66%)
# Train Epoch: 43 [0/40000 (0%)]	Loss: 0.164856
# Validation set: Average loss: 1.6733, Accuracy: 6622/10000 (66%)
# Train Epoch: 44 [0/40000 (0%)]	Loss: 0.152137
# Validation set: Average loss: 1.6757, Accuracy: 6584/10000 (66%)
# Train Epoch: 45 [0/40000 (0%)]	Loss: 0.099002
# Validation set: Average loss: 1.3990, Accuracy: 6288/10000 (63%)
# Train Epoch: 46 [0/40000 (0%)]	Loss: 0.463453
# Validation set: Average loss: 1.5458, Accuracy: 6618/10000 (66%)
# Train Epoch: 47 [0/40000 (0%)]	Loss: 0.223775
# Validation set: Average loss: 1.6362, Accuracy: 6537/10000 (65%)
# Train Epoch: 48 [0/40000 (0%)]	Loss: 0.038230
# Validation set: Average loss: 1.7363, Accuracy: 6602/10000 (66%)
# Train Epoch: 49 [0/40000 (0%)]	Loss: 0.002820
# Validation set: Average loss: 1.7745, Accuracy: 6700/10000 (67%)
# Train Epoch: 50 [0/40000 (0%)]	Loss: 0.031151
# Validation set: Average loss: 1.8398, Accuracy: 6387/10000 (64%)
# Train Epoch: 51 [0/40000 (0%)]	Loss: 0.014367
# Validation set: Average loss: 1.7325, Accuracy: 6652/10000 (67%)
# Train Epoch: 52 [0/40000 (0%)]	Loss: 0.330958
# Validation set: Average loss: 1.8001, Accuracy: 6594/10000 (66%)
# Train Epoch: 53 [0/40000 (0%)]	Loss: 0.008315
# Validation set: Average loss: 1.8234, Accuracy: 6722/10000 (67%)
# Train Epoch: 54 [0/40000 (0%)]	Loss: 0.090653
# Validation set: Average loss: 1.9675, Accuracy: 6584/10000 (66%)
# Train Epoch: 55 [0/40000 (0%)]	Loss: 0.021251
# Validation set: Average loss: 1.9555, Accuracy: 6574/10000 (66%)
# Train Epoch: 56 [0/40000 (0%)]	Loss: 0.018342
# Validation set: Average loss: 1.8605, Accuracy: 6687/10000 (67%)
# Train Epoch: 57 [0/40000 (0%)]	Loss: 0.006150
# Validation set: Average loss: 1.9632, Accuracy: 6417/10000 (64%)
# Train Epoch: 58 [0/40000 (0%)]	Loss: 0.002947
# Validation set: Average loss: 1.9421, Accuracy: 6628/10000 (66%)
# Train Epoch: 59 [0/40000 (0%)]	Loss: 0.002077
# Validation set: Average loss: 1.9113, Accuracy: 6676/10000 (67%)
# Train Epoch: 60 [0/40000 (0%)]	Loss: 0.002524
# Validation set: Average loss: 1.9435, Accuracy: 6659/10000 (67%)

# %%
# Save the model
torch.save(model.state_dict(), './relu2result/model_np.pt')

# %%
# Load the model
model = get_model(0)
model.load_state_dict(torch.load('./relu2result/model_parameters_30_np.pt', map_location=torch.device('cpu')))
model = model.to(device)

# %%
# test accuracy and losses for different test data
test_accs = []
test_losses = []
for data_name in data_names:
    dataset = get_test_data(data_name)
    # Get the last 10000 images as test data
    lenth_of_dataset = len(dataset)
    test_dataset = torch.utils.data.Subset(dataset, range(lenth_of_dataset - 10000, lenth_of_dataset))
    test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=True)
    test_acc, test_loss = test_process(model, device, test_loader)
    test_accs.append(test_acc)
    test_losses.append(test_loss)

# Plot the test accuracy for different test data with
plt.figure()
plt.bar(data_names, test_accs)
plt.title('Test accuracy for different test data')
plt.xlabel('Test data')
plt.ylabel('Test accuracy')
plt.xticks(rotation=90)
plt.show()

# Plot the test loss for different test data
plt.figure()
plt.bar(data_names, test_losses)
plt.title('Test loss for different test data')
plt.xlabel('Test data')
plt.ylabel('Test loss')
plt.xticks(rotation=90)
plt.show()


# Change the results as a pandas dataframe
test_accspd = pd.DataFrame(test_accs, index=data_names)
test_lossspd = pd.DataFrame(test_losses, index=data_names)

# Save the dataframe as a csv file
test_accspd.to_csv('./relu2result/test_accs_np_30.csv')
test_lossspd.to_csv('./relu2result/test_losses_np_30.csv')
# Out:
# Test set: Average loss: 0.0000, Accuracy: 5129/10000 (51%)
# Test set: Average loss: 0.0000, Accuracy: 2024/10000 (20%)
# Test set: Average loss: 0.0000, Accuracy: 5572/10000 (56%)
# Test set: Average loss: 0.0000, Accuracy: 5783/10000 (58%)
# Test set: Average loss: 0.0000, Accuracy: 2462/10000 (25%)
# Test set: Average loss: 0.0000, Accuracy: 4831/10000 (48%)
# Test set: Average loss: 0.0000, Accuracy: 5218/10000 (52%)
# Test set: Average loss: 0.0000, Accuracy: 6194/10000 (62%)
# Test set: Average loss: 0.0000, Accuracy: 5616/10000 (56%)
# Test set: Average loss: 0.0000, Accuracy: 5669/10000 (57%)
# Test set: Average loss: 0.0000, Accuracy: 6317/10000 (63%)
# Test set: Average loss: 0.0000, Accuracy: 5058/10000 (51%)
# Test set: Average loss: 0.0000, Accuracy: 6087/10000 (61%)
# Test set: Average loss: 0.0000, Accuracy: 5336/10000 (53%)
# Test set: Average loss: 0.0000, Accuracy: 6148/10000 (61%)
# Test set: Average loss: 0.0000, Accuracy: 4922/10000 (49%)
# Test set: Average loss: 0.0000, Accuracy: 5565/10000 (56%)
# Test set: Average loss: 0.0000, Accuracy: 6151/10000 (62%)
# Test set: Average loss: 0.0000, Accuracy: 5435/10000 (54%)

# %%
# Show the acc graph again as previous one is not clear
plt.figure(figsize=(12, 5))
plt.bar(data_names, test_accs)
plt.suptitle('Test accuracy for different test data')
plt.title('Average of 20 results: ' + str(np.mean(test_accs)))
plt.xlabel('Test data')
plt.ylabel('Test accuracy')
plt.xticks(rotation=90)
plt.ylim(0, 1)
for i, v in enumerate(test_accs):
    plt.text(i - 0.5, v + 0.01, str(v))
plt.show()
