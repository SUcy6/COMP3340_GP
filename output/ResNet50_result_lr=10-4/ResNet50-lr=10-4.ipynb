# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.optim.lr_scheduler import StepLR
import torchvision
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import tarfile
import os
import csv
import shutil

# %%
# Download Oxford 17 Category Flower Dataset
# !wget http://www.robots.ox.ac.uk/~vgg/data/flowers/17/17flowers.tgz -O 17flowers.tgz
# Out:
# --2022-10-25 15:44:34--  http://www.robots.ox.ac.uk/~vgg/data/flowers/17/17flowers.tgz
# Resolving www.robots.ox.ac.uk (www.robots.ox.ac.uk)... 129.67.94.2
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.robots.ox.ac.uk/~vgg/data/flowers/17/17flowers.tgz [following]
# --2022-10-25 15:44:35--  https://www.robots.ox.ac.uk/~vgg/data/flowers/17/17flowers.tgz
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60270631 (57M) [application/x-gzip]
# Saving to: ‘17flowers.tgz’
#
# 17flowers.tgz       100%[===================>]  57.48M  11.2MB/s    in 6.4s
#
# 2022-10-25 15:44:42 (9.02 MB/s) - ‘17flowers.tgz’ saved [60270631/60270631]

# %%
# Split the images in ./jpg into 17 folders
# !cd ./jpg && for i in {1..17}; do mkdir $i; done
# Out:
# mkdir: cannot create directory ‘1’: File exists
# mkdir: cannot create directory ‘2’: File exists
# mkdir: cannot create directory ‘3’: File exists
# mkdir: cannot create directory ‘4’: File exists
# mkdir: cannot create directory ‘5’: File exists
# mkdir: cannot create directory ‘6’: File exists
# mkdir: cannot create directory ‘7’: File exists
# mkdir: cannot create directory ‘8’: File exists
# mkdir: cannot create directory ‘9’: File exists
# mkdir: cannot create directory ‘10’: File exists
# mkdir: cannot create directory ‘11’: File exists
# mkdir: cannot create directory ‘12’: File exists
# mkdir: cannot create directory ‘13’: File exists
# mkdir: cannot create directory ‘14’: File exists
# mkdir: cannot create directory ‘15’: File exists
# mkdir: cannot create directory ‘16’: File exists
# mkdir: cannot create directory ‘17’: File exists

# %%
# Move image_xxxx.jpg to folder (((xxxx-1)//80) + 1)
# !cd ./jpg && for i in {0001..1360}; do mv "image_$i.jpg" $(((i-1)/80 + 1)); done
# Out:
# mv: cannot stat 'image_0001.jpg': No such file or directory
# mv: cannot stat 'image_0002.jpg': No such file or directory
# mv: cannot stat 'image_0003.jpg': No such file or directory
# mv: cannot stat 'image_0004.jpg': No such file or directory
# mv: cannot stat 'image_0005.jpg': No such file or directory
# mv: cannot stat 'image_0006.jpg': No such file or directory
# mv: cannot stat 'image_0007.jpg': No such file or directory
# /bin/bash: 0008: value too great for base (error token is "0008")

# %%
file = tarfile.open("17flowers.tgz")
file.extractall("data_flowers/")
dir = "data_flowers/jpg/"
arr = os.listdir(dir)

# uncomment this if you just download a new flower17 dataset
# otherwise, you don't need to remove this file again
os.remove("data_flowers/jpg/files.txt") # this file is useless

# %%
with open('flowers.csv', mode = "w") as f:
  f.truncate()
with open('flowers.csv', mode='a', newline='') as f:
  csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
  csv_writer.writerow(list(np.array(["img_id", "classes"])))

dir = "data_flowers/jpg/"
arr = os.listdir(dir)
arr.sort
n = 0
for img in arr:
  if img[:6] == "image_":
    img_id = img[:-4]
    id = img[6:-4]
    id.lstrip('0')
    id = int(id)
    if (id%80 != 0):
      label = (id//80)+1
    else:
      label = id//80
    row = list(np.array([img_id, label]))

    # Export to CSV
    with open('flowers.csv', mode='a', newline='') as f:
      csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
      csv_writer.writerow(row)

# %%
# data frame
df = pd.read_csv("flowers.csv")

# attribute for our images
df = df[['img_id', 'classes']]

# %%
# !mkdir data

# %%
# %cd data
# Out:
# /content/data

# %%
# make folder for each class
# !mkdir {f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f11,f12,f13,f14,f15,f16,f17}

# %%
# separate images to each class folder
for i, (_, i_row) in enumerate(df.iterrows()):
  file_class = i_row['classes']
  file_name = i_row['img_id'] + ".jpg"
  file_path = "/content/data_flowers/jpg/" + i_row['img_id'] + ".jpg"
  shutil.copyfile(file_path, 'f' + str(file_class) + "/" + file_name)

# %%
# %cd ..
# Out:
# /content

# %%
# Build the ResNet50 model
def get_model():
    model = torchvision.models.resnet50(weights="ResNet50_Weights.IMAGENET1K_V1")

    model.fc = nn.Linear(2048, 17)
    return model

# %%
model = torchvision.models.resnet50(weights="ResNet50_Weights.IMAGENET1K_V1")
print(model)

# %%
# Build the transformer for the dataset in training, validation and testing
transformer = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# Build the dataset in training, validation and testing from ./jpg where the images are stored in 17 folders
train_dataset = torchvision.datasets.ImageFolder(root='./data', transform=transformer)

# Split the dataset into training, validation and testing
train_size = int(0.8 * len(train_dataset))
val_size = int(0.1 * len(train_dataset))
test_size = len(train_dataset) - train_size - val_size
train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(train_dataset, [train_size, val_size, test_size])

# %%
# Set the batch size used for model training
batch_sizes =[4, 32, 64]

# %%
# Define the training function and return loss
def train(model, device, train_loader, optimizer, epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.cross_entropy(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))
    return loss.item()

# Define the validation function and return loss
def validate(model, device, valid_loader):
    model.eval()
    valid_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in valid_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            valid_loss += F.cross_entropy(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    valid_loss /= len(valid_loader.dataset)
    print('Validation set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)'.format(
        valid_loss, correct, len(valid_loader.dataset),
        100. * correct / len(valid_loader.dataset)))
    return valid_loss

# Define the testing function and return accuracy
def test(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.cross_entropy(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    print('Test set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return correct / len(test_loader.dataset)

# %%
# Define the optimizer
def get_optimizer(model, lr):
    optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=0.9)
    return optimizer

# Define the training process
def train_process(model, device, train_loader, valid_loader, optimizer, epochs, test_loader):
    train_loss = []
    valid_loss = []
    test_acc = []
    for epoch in range(1, epochs + 1):
        train_loss.append(train(model, device, train_loader, optimizer, epoch))
        valid_loss.append(validate(model, device, valid_loader))
        test_acc.append(test(model, device, test_loader))
    return train_loss, valid_loss, test_acc

# %%
# Define the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
# Start training and testing
train_losses = []
valid_losses = []
test_accs = []
i = 0
for batch_size in batch_sizes:
    print('Batch size: {}'.format(batch_size))
    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
    test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=True)
    model = get_model()
    model = model.to(device)
    optimizer = get_optimizer(model, 0.0001) # lr
    train_loss, valid_loss, test_acc = train_process(model, device, train_loader, val_loader, optimizer, 60, test_loader)
    train_losses.append(train_loss)
    valid_losses.append(valid_loss)
    test_accs.append(test_acc)
    i += 1
# Out:
# Batch size: 4
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]
# Train Epoch: 1 [0/1088 (0%)]	Loss: 2.757602
# Train Epoch: 1 [400/1088 (37%)]	Loss: 2.517982
# Train Epoch: 1 [800/1088 (74%)]	Loss: 2.288082
# Validation set: Average loss: 2.0002, Accuracy: 100/136 (74%)
# Test set: Average loss: 2.1072, Accuracy: 76/136 (56%)
# Train Epoch: 2 [0/1088 (0%)]	Loss: 2.016632
# Train Epoch: 2 [400/1088 (37%)]	Loss: 2.228906
# Train Epoch: 2 [800/1088 (74%)]	Loss: 1.530635
# Validation set: Average loss: 1.1437, Accuracy: 126/136 (93%)
# Test set: Average loss: 1.2324, Accuracy: 120/136 (88%)
# Train Epoch: 3 [0/1088 (0%)]	Loss: 1.854229
# Train Epoch: 3 [400/1088 (37%)]	Loss: 1.643402
# Train Epoch: 3 [800/1088 (74%)]	Loss: 1.072070
# Validation set: Average loss: 0.6454, Accuracy: 130/136 (96%)
# Test set: Average loss: 0.6924, Accuracy: 128/136 (94%)
# Train Epoch: 4 [0/1088 (0%)]	Loss: 0.754610
# Train Epoch: 4 [400/1088 (37%)]	Loss: 1.704201
# Train Epoch: 4 [800/1088 (74%)]	Loss: 1.069968
# Validation set: Average loss: 0.3704, Accuracy: 132/136 (97%)
# Test set: Average loss: 0.3861, Accuracy: 129/136 (95%)
# Train Epoch: 5 [0/1088 (0%)]	Loss: 0.505951
# Train Epoch: 5 [400/1088 (37%)]	Loss: 1.421985
# Train Epoch: 5 [800/1088 (74%)]	Loss: 1.176120
# Validation set: Average loss: 0.2153, Accuracy: 132/136 (97%)
# Test set: Average loss: 0.
Accuracy: 132/136 (97%)
# Test set: Average loss: 0.5878, Accuracy: 128/136 (94%)
# Train Epoch: 35 [0/1088 (0%)]	Loss: 0.642689
# Validation set: Average loss: 0.5463, Accuracy: 132/136 (97%)
# Test set: Average loss: 0.5677, Accuracy: 128/136 (94%)
# Train Epoch: 36 [0/1088 (0%)]	Loss: 0.528819
# Validation set: Average loss: 0.5262, Accuracy: 132/136 (97%)
# Test set: Average loss: 0.5457, Accuracy: 127/136 (93%)
# Train Epoch: 37 [0/1088 (0%)]	Loss: 0.514969
# Validation set: Average loss: 0.5043, Accuracy: 132/136 (97%)
# Test set: Average loss: 0.5194, Accuracy: 129/136 (95%)
# Train Epoch: 38 [0/1088 (0%)]	Loss: 0.517587
# Validation set: Average loss: 0.4836, Accuracy: 132/136 (97%)
# Test set: Average loss: 0.4973, Accuracy: 129/136 (95%)
# Train Epoch: 39 [0/1088 (0%)]	Loss: 0.453687
# Validation set: Average loss: 0.4721, Accuracy: 132/136 (97%)
# Test set: Average loss: 0.4852, Accuracy: 129/136 (95%)
# Train Epoch: 40 [0/1088 (0%)]	Loss: 0.402738
# Validation set: Average loss: 0.4517, Accuracy: 132/136 (97%)
# Test set: Average loss: 0.4667, Accuracy: 129/136 (95%)
# Train Epoch: 41 [0/1088 (0%)]	Loss: 0.451336
# Validation set: Average loss: 0.4421, Accuracy: 132/136 (97%)
# Test set: Average loss: 0.4518, Accuracy: 130/136 (96%)
# Train Epoch: 42 [0/1088 (0%)]	Loss: 0.401925
# Validation set: Average loss: 0.4223, Accuracy: 132/136 (97%)
# Test set: Average loss: 0.4342, Accuracy: 129/136 (95%)
# Train Epoch: 43 [0/1088 (0%)]	Loss: 0.417352
# Validation set: Average loss: 0.4097, Accuracy: 132/136 (97%)
# Test set: Average loss: 0.4189, Accuracy: 130/136 (96%)
# Train Epoch: 44 [0/1088 (0%)]	Loss: 0.400298
# Validation set: Average loss: 0.3984, Accuracy: 132/136 (97%)
# Test set: Average loss: 0.4067, Accuracy: 130/136 (96%)
# Train Epoch: 45 [0/1088 (0%)]	Loss: 0.299874
# Validation set: Average loss: 0.3882, Accuracy: 132/136 (97%)
# Test set: Average loss: 0.3926, Accuracy: 130/136 (96%)
# Train Epoch: 46 [0/1088 (0%)]	Loss: 0.331021
# Validation set: Average loss: 0.3755, Accuracy: 132/136 (97%)
# Test set: Average loss: 0.3798, Accuracy: 131/136 (96%)
# Train Epoch: 47 [0/1088 (0%)]	Loss: 0.356642
# Validation set: Average loss: 0.3668, Accuracy: 132/136 (97%)
# Test set: Average loss: 0.3700, Accuracy: 131/136 (96%)
# Train Epoch: 48 [0/1088 (0%)]	Loss: 0.355150
# Validation set: Average loss: 0.3561, Accuracy: 132/136 (97%)
# Test set: Average loss: 0.3587, Accuracy: 130/136 (96%)
# Train Epoch: 49 [0/1088 (0%)]	Loss: 0.274925
# Validation set: Average loss: 0.3457, Accuracy: 132/136 (97%)
# Test set: Average loss: 0.3498, Accuracy: 131/136 (96%)
# Train Epoch: 50 [0/1088 (0%)]	Loss: 0.313228
# Validation set: Average loss: 0.3366, Accuracy: 132/136 (97%)
# Test set: Average loss: 0.3401, Accuracy: 130/136 (96%)
# Train Epoch: 51 [0/1088 (0%)]	Loss: 0.245367
# Validation set: Average loss: 0.3279, Accuracy: 132/136 (97%)
# Test set: Average loss: 0.3270, Accuracy: 131/136 (96%)
# Train Epoch: 52 [0/1088 (0%)]	Loss: 0.207176
# Validation set: Average loss: 0.3204, Accuracy: 132/136 (97%)
# Test set: Average loss: 0.3185, Accuracy: 130/136 (96%)
# Train Epoch: 53 [0/1088 (0%)]	Loss: 0.232153
# Validation set: Average loss: 0.3140, Accuracy: 132/136 (97%)
# Test set: Average loss: 0.3109, Accuracy: 131/136 (96%)
# Train Epoch: 54 [0/1088 (0%)]	Loss: 0.252574
# Validation set: Average loss: 0.3071, Accuracy: 132/136 (97%)
# Test set: Average loss: 0.3062, Accuracy: 131/136 (96%)
# Train Epoch: 55 [0/1088 (0%)]	Loss: 0.172080
# Validation set: Average loss: 0.2985, Accuracy: 132/136 (97%)
# Test set: Average loss: 0.3008, Accuracy: 131/136 (96%)
# Train Epoch: 56 [0/1088 (0%)]	Loss: 0.213008
# Validation set: Average loss: 0.2919, Accuracy: 132/136 (97%)
# Test set: Average loss: 0.2913, Accuracy: 131/136 (96%)
# Train Epoch: 57 [0/1088 (0%)]	Loss: 0.184196
# Validation set: Average loss: 0.2850, Accuracy: 132/136 (97%)
# Test set: Average loss: 0.2850, Accuracy: 131/136 (96%)
# Train Epoch: 58 [0/1088 (0%)]	Loss: 0.174734
# Validation set: Average loss: 0.2772, Accuracy: 132/136 (97%)
# Test set: Average loss: 0.2771, Accuracy: 131/136 (96%)
# Train Epoch: 59 [0/1088 (0%)]	Loss: 0.195383
# Validation set: Average loss: 0.2755, Accuracy: 132/136 (97%)
# Test set: Average loss: 0.2684, Accuracy: 131/136 (96%)
# Train Epoch: 60 [0/1088 (0%)]	Loss: 0.182727
# Validation set: Average loss: 0.2740, Accuracy: 132/136 (97%)
# Test set: Average loss: 0.2687, Accuracy: 131/136 (96%)

# %%
# Plot the training for different batch sizes
plt.figure(figsize=(10, 6))
for i in range(len(batch_sizes)):
    plt.plot(train_losses[i], label='batch size = {}'.format(batch_sizes[i]))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Losses')
plt.legend()

# %%
# Plot the validation for different batch sizes
plt.figure(figsize=(10, 6))
for i in range(len(batch_sizes)):
    plt.plot(valid_losses[i], label='batch size = {}'.format(batch_sizes[i]))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Validation Losses')
plt.legend()

# %%
# Plot the test accuracy for different batch sizes
plt.figure(figsize=(10, 6))
for i in range(len(batch_sizes)):
    plt.plot(test_accs[i], label='batch size = {}'.format(batch_sizes[i]))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Test Accuracies')
plt.legend()

# %%
# !mkdir ResNet50_result

# %%
# Change the train_losses, valid_losses, test_losses, test_accs as different pandas dataframes
train_lossespd = pd.DataFrame({'batch_size_4': train_losses[0], 'batch_size_32': train_losses[1], 'batch_size_64': train_losses[2]})
valid_lossespd = pd.DataFrame({'batch_size_4': valid_losses[0], 'batch_size_32': valid_losses[1], 'batch_size_64': valid_losses[2]})
test_accspd = pd.DataFrame({'batch_size_4': test_accs[0], 'batch_size_32': test_accs[1], 'batch_size_64': test_accs[2]})

# Save the train_losses, valid_losses, test_losses, test_accs as csv files
train_lossespd.to_csv('./ResNet50_result/train_losses.csv', index=True)
valid_lossespd.to_csv('./ResNet50_result/valid_losses.csv', index=True)
test_accspd.to_csv('./ResNet50_result/test_accs.csv', index=True)
