# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.optim.lr_scheduler import StepLR
import torchvision
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import tarfile
import os
import csv
import shutil

# %%
pip install pandas
# Out:
# Collecting pandas
#   Using cached pandas-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
# Requirement already satisfied: pytz>=2017.3 in ./anaconda3/envs/comp3340/lib/python3.7/site-packages (from pandas) (2022.2.1)
# Requirement already satisfied: numpy>=1.17.3 in ./anaconda3/envs/comp3340/lib/python3.7/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in ./anaconda3/envs/comp3340/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in ./anaconda3/envs/comp3340/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Installing collected packages: pandas
# Successfully installed pandas-1.3.5
# Note: you may need to restart the kernel to use updated packages.

# %%
# Download Oxford 17 Category Flower Dataset
# !wget http://www.robots.ox.ac.uk/~vgg/data/flowers/17/17flowers.tgz -O 17flowers.tgz
# Out:
# --2022-10-26 14:14:02--  http://www.robots.ox.ac.uk/~vgg/data/flowers/17/17flowers.tgz
# Resolving www.robots.ox.ac.uk (www.robots.ox.ac.uk)... 129.67.94.2
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.robots.ox.ac.uk/~vgg/data/flowers/17/17flowers.tgz [following]
# --2022-10-26 14:14:03--  https://www.robots.ox.ac.uk/~vgg/data/flowers/17/17flowers.tgz
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60270631 (57M) [application/x-gzip]
# Saving to: ‘17flowers.tgz’
#
# 17flowers.tgz       100%[===================>]  57.48M  12.8MB/s    in 5.9s
#
# 2022-10-26 14:14:10 (9.70 MB/s) - ‘17flowers.tgz’ saved [60270631/60270631]

# %%
file = tarfile.open("17flowers.tgz")
file.extractall("data_flowers/")
dir = "data_flowers/jpg/"
arr = os.listdir(dir)

# uncomment this if you just download a new flower17 dataset
# otherwise, you don't need to remove this file again
os.remove("data_flowers/jpg/files.txt") # this file is useless

# %%
with open('flowers.csv', mode = "w") as f:
  f.truncate()
with open('flowers.csv', mode='a', newline='') as f:
  csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
  csv_writer.writerow(list(np.array(["img_id", "classes"])))

dir = "data_flowers/jpg/"
arr = os.listdir(dir)
arr.sort
n = 0
for img in arr:
  if img[:6] == "image_":
    img_id = img[:-4]
    id = img[6:-4]
    id.lstrip('0')
    id = int(id)
    if (id%80 != 0):
      label = (id//80)+1
    else:
      label = id//80
    row = list(np.array([img_id, label]))

    # Export to CSV
    with open('flowers.csv', mode='a', newline='') as f:
      csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
      csv_writer.writerow(row)

# %%
# data frame
df = pd.read_csv("flowers.csv")

# attribute for our images
df = df[['img_id', 'classes']]

# %%
# !mkdir data

# %%
# %cd data
# Out:
# /userhome/cs2/scytina6/data

# %%
# make folder for each class
# !mkdir {f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f11,f12,f13,f14,f15,f16,f17}

# %%
# separate images to each class folder
for i, (_, i_row) in enumerate(df.iterrows()):
  file_class = i_row['classes']
  file_name = i_row['img_id'] + ".jpg"
  file_path = "/userhome/cs2/scytina6/data_flowers/jpg/" + i_row['img_id'] + ".jpg"
  shutil.copyfile(file_path, 'f' + str(file_class) + "/" + file_name)

# %%
# %cd ..
# Out:
# /userhome/cs2/scytina6

# %%
# Build the ResNet50 model
def get_model():
    model = torchvision.models.resnet50(pretrained=False)

    model.fc = nn.Linear(2048, 17)
    return model

# %%
# model = torchvision.models.resnet50(weights="ResNet50_Weights.IMAGENET1K_V1")
model = torchvision.models.resnet50(pretrained=False)
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
# Build the transformer for the dataset in training, validation and testing
transformer = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# Build the dataset in training, validation and testing from ./jpg where the images are stored in 17 folders
train_dataset = torchvision.datasets.ImageFolder(root='./data', transform=transformer)

# Split the dataset into training, validation and testing
train_size = int(0.8 * len(train_dataset))
val_size = int(0.1 * len(train_dataset))
test_size = len(train_dataset) - train_size - val_size
train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(train_dataset, [train_size, val_size, test_size])

# %%
# Set the batch size used for model training
batch_sizes =[4, 32, 64]

# %%
batch_sizes =[64]

# %%
# Define the training function and return loss
def train(model, device, train_loader, optimizer, epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.cross_entropy(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))
    return loss.item()

# Define the validation function and return loss
def validate(model, device, valid_loader):
    model.eval()
    valid_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in valid_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            valid_loss += F.cross_entropy(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    valid_loss /= len(valid_loader.dataset)
    print('Validation set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)'.format(
        valid_loss, correct, len(valid_loader.dataset),
        100. * correct / len(valid_loader.dataset)))
    return valid_loss

# Define the testing function and return accuracy
def test(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.cross_entropy(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    print('Test set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return correct / len(test_loader.dataset)

# %%
# Define the optimizer
def get_optimizer(model, lr):
    optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=0.9)
    return optimizer

# Define the training process
def train_process(model, device, train_loader, valid_loader, optimizer, epochs, test_loader):
    train_loss = []
    valid_loss = []
    test_acc = []
    for epoch in range(1, epochs + 1):
        train_loss.append(train(model, device, train_loader, optimizer, epoch))
        valid_loss.append(validate(model, device, valid_loader))
        test_acc.append(test(model, device, test_loader))
    return train_loss, valid_loss, test_acc

# %%
# Define the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
# Start training and testing
train_losses = []
valid_losses = []
test_accs = []
i = 0
for batch_size in batch_sizes:
    print('Batch size: {}'.format(batch_size))
    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
    test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=True)
    model = get_model()
    model = model.to(device)
    optimizer = get_optimizer(model, 0.001) # lr
    train_loss, valid_loss, test_acc = train_process(model, device, train_loader, val_loader, optimizer, 60, test_loader)
    train_losses.append(train_loss)
    valid_losses.append(valid_loss)
    test_accs.append(test_acc)
    i += 1
# Out:
# Batch size: 4
# Train Epoch: 1 [0/1088 (0%)]	Loss: 2.800582
# Train Epoch: 1 [400/1088 (37%)]	Loss: 3.793044
# Train Epoch: 1 [800/1088 (74%)]	Loss: 5.324747
# Validation set: Average loss: 3.4816, Accuracy: 12/136 (9%)
# Test set: Average loss: 3.4330, Accuracy: 15/136 (11%)
# Train Epoch: 2 [0/1088 (0%)]	Loss: 2.136441
# Train Epoch: 2 [400/1088 (37%)]	Loss: 2.785710
# Train Epoch: 2 [800/1088 (74%)]	Loss: 1.742702
# Validation set: Average loss: 3.3186, Accuracy: 25/136 (18%)
# Test set: Average loss: 3.2819, Accuracy: 20/136 (15%)
# Train Epoch: 3 [0/1088 (0%)]	Loss: 3.788161
# Train Epoch: 3 [400/1088 (37%)]	Loss: 3.135407
# Train Epoch: 3 [800/1088 (74%)]	Loss: 2.260335
# Validation set: Average loss: 5.2853, Accuracy: 22/136 (16%)
# Test set: Average loss: 5.4459, Accuracy: 19/136 (14%)
# Train Epoch: 4 [0/1088 (0%)]	Loss: 3.861839
# Train Epoch: 4 [400/1088 (37%)]	Loss: 2.130336
# Train Epoch: 4 [800/1088 (74%)]	Loss: 3.695379
# Validation set: Average loss: 6.9401, Accuracy: 25/136 (18%)
# Test set: Average loss: 4.8082, Accuracy: 18/136 (13%)
# Train Epoch: 5 [0/1088 (0%)]	Loss: 3.336972
# Train Epoch: 5 [400/1088 (37%)]	Loss: 3.384834
# Train Epoch: 5 [800/1088 (74%)]	Loss: 2.564882
# Validation set: Average loss: 3.2641, Accuracy: 32/136 (24%)
# Test set: Average loss: 2.6608, Accuracy: 33/136 (24%)
# Train Epoch: 6 [0/1088 (0%)]	Loss: 2.325328
# Train Epoch: 6 [400/1088 (37%)]	Loss: 2.983418
# Train Epoch: 6 [800/1088 (74%)]	Loss: 2.697670
# Validation set: Average loss: 3.4396, Accuracy: 45/136 (33%)
# Test set: Average loss: 3.0982, Accuracy: 36/136 (26%)
# Train Epoch: 7 [0/1088 (0%)]	Loss: 2.320495
# Train Epoch: 7 [400/1088 (37%)]	Loss: 2.843854
# Train Epoch: 7 [800/1088 (74%)]	Loss: 2.571039
# Validation set: Average loss: 11.4583, Accuracy: 32/136 (24%)
# Test set: Average loss: 8.2097, Accuracy: 49/136 (36%)
# Train Epoch: 8 [0/1088 (0%)]	Loss: 2.247366
# Train Epoch: 8 [400/1088 (37%)]	Loss: 1.175713
# Train Epoch: 8 [800/1088 (74%)]	Loss: 2.100035
# Validation set: Average loss: 5.7726, Accuracy: 36/136 (26%)
# Test set: Average loss: 4.7117, Accuracy: 31/136 (23%)
# Train Epoch: 9 [0/1088 (0%)]	Loss: 1.492300
# Train Epoch: 9 [400/1088 (37%)]	Loss: 1.670564
# Train Epoch: 9 [800/1088 (74%)]	Loss: 1.512635
# Validation set: Average loss: 7.4045, Accuracy: 44/136 (32%)
# Test set: Average loss: 4.3470, Accuracy: 48/136 (35%)
# Train Epoch: 10 [0/1088 (0%)]	Loss: 1.128715
# Train Epoch: 10 [400/1088 (37%)]	Loss: 2.838278
# Train Epoch: 10 [800/1088 (74%)]	Loss: 1.601351
# Validation set: Average loss: 8.3897, Accuracy: 47/136 (35%)
# Test set: Average loss: 7.1522, Accuracy: 45/136 (33%)
# Train Epoch: 11 [0/1088 (0%)]	Loss: 2.206471
# Train Epoch: 11 [400/1088 (37%)]	Loss: 0.777530
# Train Epoch: 11 [800/1088 (74%)]	Loss: 1.093068
# Validation set: Average loss: 6.0417, Accuracy: 46/136 (34%)
# Test set: Average loss: 5.2138, Accuracy: 50/136 (37%)
# Train Epoch: 12 [0/1088 (0%)]	Loss: 3.678224
# Train Epoch: 12 [400/1088 (37%)]	Loss: 1.028367
# Train Epoch: 12 [800/1088 (74%)]	Loss: 1.505681
# Validation set: Average loss: 7.4040, Accuracy: 60/136 (44%)
# Test set: Average loss: 5.2144, Accuracy: 56/136 (41%)
# Train Epoch: 13 [0/1088 (0%)]	Loss: 1.555818
# Train Epoch: 13 [400/1088 (37%)]	Loss: 1.427489
# Train Epoch: 13 [800/1088 (74%)]	Loss: 1.452784
# Validation set: Average loss: 3.3031, Accuracy: 58/136 (43%)
# Test set: Average loss: 2.8708, Accuracy: 57/136 (42%)
# Train Epoch: 14 [0/1088 (0%)]	Loss: 1.368772
# Train Epoch: 14 [400/1088 (37%)]	Loss: 1.182645
# Train Epoch: 14 [800/1088 (74%)]	Loss: 1.765698
# Validation set: Average loss: 4.4203, Accuracy: 57/136 (42%)
# Test set: Average loss: 3.1845, Accuracy: 58/136 (43%)
# Train Epoch: 15 [0/1088 (0%)]	Loss: 1.186395
# Train Epoch: 15 [400/1088 (37%)]	Loss: 0.480993
# Train Epoch: 15 [800/1088 (74%)]	Loss: 1.338730
# Validation set: Average loss: 5.5976, Accuracy: 58/136 (43%)
# Test set: Average loss: 3.0273, Accuracy: 55/136 (40%)
# Train Epoch: 16 [0/1088 (0%)]	Loss: 2.238509
# Train Epoch: 16 [400/1088 (37%)]	Loss: 0.294968
# Train Epoch: 16 [800/1088 (74%)]	Loss: 1.639031
# Validation set: Average loss: 9.1418, Accuracy: 60/136 (44%)
# Test set: Average loss: 6.2573, Accuracy: 58/136 (43%)
# Train Epoch: 17 [0/1088 (0%)]	Loss: 1.514342
# Train Epoch: 17 [400/1088 (37%)]	Loss: 2.142462
# Train Epoch: 17 [800/1088 (74%)]	Loss: 1.551004
# Validation set: Average loss: 4.2630, Accuracy: 56/136 (41%)
# Test set: Average loss: 2.9198, Accuracy: 68/136 (50%)
# Train Epoch: 18 [0/1088 (0%)]	Loss: 0.818278
# Train Epoch: 18 [400/1088 (37%)]	Loss: 1.244735
# Train Epoch: 18 [800/1088 (74%)]	Loss: 1.807889
# Validation set: Average loss: 6.0451, Accuracy: 58/136 (43%)
# Test set: Average loss: 3.9746, Accuracy: 64/136 (47%)
# Train Epoch: 19 [0/1088 (0%)]	Loss: 0.901274
# Train Epoch: 19 [400/1088 (37%)]	Loss: 0.606716
# Train Epoch: 19 [800/1088 (74%)]	Loss: 1.020297
# Validation set: Average loss: 9.5082, Accuracy: 52/136 (38%)
# Test set: Average loss: 5.1910, Accuracy: 59/136 (43%)
# Train Epoch: 20 [0/1088 (0%)]	Loss: 2.056695
# Train Epoch: 20 [400/1088 (37%)]	Loss: 0.866925
# Train Epoch: 20 [800/1088 (74%)]	Loss: 0.717221
# Validation set: Average loss: 3.3649, Accuracy: 65/136 (48%)
# Test set: Average loss: 2.9979, Accuracy: 65/136 (48%)
# Train Epoch: 21 [0/1088 (0%)]	Loss: 1.304998
# Train Epoch: 21 [400/1088 (37%)]	Loss: 1.646805
# Train Epoch: 21 [800/1088 (74%)]	Loss: 1.923262
# Validation set: Average loss: 5.0357, Accuracy: 64/136 (47%)
# Test set: Average loss: 4.7254, Accuracy: 67/136 (49%)
# Train Epoch: 22 [0/1088 (0%)]	Loss: 2.389410
# Train Epoch: 22 [400/1088 (37%)]	Loss: 1.176521
# Train Epoch: 22 [800/1088 (74%)]	Loss: 1.661170
# Validation set: Average loss: 6.8679, Accuracy: 78/136 (57%)
# Test set: Average loss: 3.9702, Accuracy: 78/136 (57%)
# Train Epoch: 23 [0/1088 (0%)]	Loss: 0.949370
# Train Epoch: 23 [400/1088 (37%)]	Loss: 1.072358
# Train Epoch: 23 [800/1088 (74%)]	Loss: 1.340153
# Validation set: Average loss: 4.6281, Accuracy: 66/136 (49%)
# Test set: Average loss: 3.6373, Accuracy: 79/136 (58%)
# Train Epoch: 24 [0/1088 (0%)]	Loss: 1.078211
# Train Epoch: 24 [400/1088 (37%)]	Loss: 1.108103
# Train Epoch: 24 [800/1088 (74%)]	Loss: 1.596074
# Validation set: Average loss: 6.9430, Accuracy: 68/136 (50%)
# Test set: Average loss: 3.3533, Accuracy: 72/136 (53%)
# Train Epoch: 25 [0/1088 (0%)]	Loss: 0.198358
# Train Epoch: 25 [400/1088 (37%)]	Loss: 1.224833
# Train Epoch: 25 [800/1088 (74%)]	Loss: 0.372183
# Validation set: Average loss: 7.8759, Accuracy: 72/136 (53%)
# Test set: Average loss: 3.7540, Accuracy: 71/136 (52%)
# Train Epoch: 26 [0/1088 (0%)]	Loss: 0.605455
# Train Epoch: 26 [400/1088 (37%)]	Loss: 1.420750
# Train Epoch: 26 [800/1088 (74%)]	Loss: 1.212625
# Validation set: Average loss: 3.6755, Accuracy: 79/136 (58%)
# Test set: Average loss: 2.6145, Accuracy: 79/136 (58%)
# Train Epoch: 27 [0/1088 (0%)]	Loss: 0.812919
# Train Epoch: 27 [400/1088 (37%)]	Loss: 1.446610
# Train Epoch: 27 [800/1088 (74%)]	Loss: 1.833514
# Validation set: Average loss: 5.6000, Accuracy: 72/136 (53%)
# Test set: Average loss: 4.0345, Accuracy: 78/136 (57%)
# Train Epoch: 28 [0/1088 (0%)]	Loss: 0.362946
# Train Epoch: 28 [400/1088 (37%)]	Loss: 1.689946
# Train Epoch: 28 [800/1088 (74%)]	Loss: 0.857479
# Validation set: Average loss: 5.2044, Accuracy: 71/136 (52%)
# Test set: Average loss: 3.8300, Accuracy: 73/136 (54%)
# Train Epoch: 29 [0/1088 (0%)]	Loss: 0.277289
# Train Epoch: 29 [400/1088 (37%)]	Loss: 1.897380
# Train Epoch: 29 [800/1088 (74%)]	Loss: 0.314241
# Validation set: Average loss: 6.3813, Accuracy: 72/136 (53%)
# Test set: Average loss: 5.5070, Accuracy: 70/136 (51%)
# Train Epoch: 30 [0/1088 (0%)]	Loss: 0.393225
# Train Epoch: 30 [400/1088 (37%)]	Loss: 1.038160
# Train Epoch: 30 [800/1088 (74%)]	Loss: 1.101918
# Validation set: Average loss: 2.5553, Accuracy: 83/136 (61%)
# Test set: Average loss: 1.8059, Accuracy: 85/136 (62%)
# Train Epoch: 31 [0/1088 (0%)]	Loss: 1.170390
# Train Epoch: 31 [400/1088 (37%)]	Loss: 1.946622
# Train Epoch: 31 [800/1088 (74%)]	Loss: 0.882615
# Validation set: Average loss: 7.0260, Accuracy: 80/136 (59%)
# Test set: Average loss: 4.9485, Accuracy: 85/136 (62%)
# Train Epoch: 32 [0/1088 (0%)]	Loss: 0.476791
# Train Epoch: 32 [400/1088 (37%)]	Loss: 0.067177
# Train Epoch: 32 [800/1088 (74%)]	Loss: 0.918691
# Validation set: Average loss: 2.7980, Accuracy: 82/136 (60%)
# Test set: Average loss: 1.9763, Accuracy: 91/136 (67%)
# Train Epoch: 33 [0/1088 (0%)]	Loss: 1.482717
# Train Epoch: 33 [400/1088 (37%)]	Loss: 0.460100
# Train Epoch: 33 [800/1088 (74%)]	Loss: 0.024048
# Validation set: Average loss: 13.1734, Accuracy: 79/136 (58%)
# Test set: Average loss: 9.5465, Accuracy: 79/136 (58%)
# Train Epoch: 34 [0/1088 (0%)]	Loss: 0.244189
# Train Epoch: 34 [400/1088 (37%)]	Loss: 0.037358
# Train Epoch: 34 [800/1088 (74%)]	Loss: 0.397974
# Validation set: Average loss: 7.0292, Accuracy: 83/136 (61%)
# Test set: Average loss: 4.4404, Accuracy: 82/136 (60%)
# Train Epoch: 35 [0/1088 (0%)]	Loss: 0.686489
# Train Epoch: 35 [400/1088 (37%)]	Loss: 1.523694
# Train Epoch: 35 [800/1088 (74%)]	Loss: 0.012689
# Validation set: Average loss: 13.6239, Accuracy: 68/136 (50%)
# Test set: Average loss: 8.0627, Accuracy: 69/136 (51%)
# Train Epoch: 36 [0/1088 (0%)]	Loss: 0.411806
# Train Epoch: 36 [400/1088 (37%)]	Loss: 2.474754
# Train Epoch: 36 [800/1088 (74%)]	Loss: 1.232212
# Validation set: Average loss: 11.5178, Accuracy: 82/136 (60%)
# Test set: Average loss: 7.5751, Accuracy: 80/136 (59%)
# Train Epoch: 37 [0/1088 (0%)]	Loss: 0.045778
# Train Epoch: 37 [400/1088 (37%)]	Loss: 0.011471
# Train Epoch: 37 [800/1088 (74%)]	Loss: 0.190487
# Validation set: Average loss: 4.7411, Accuracy: 75/136 (55%)
# Test set: Average loss: 3.3137, Accuracy: 82/136 (60%)
# Train Epoch: 38 [0/1088 (0%)]	Loss: 0.105259
# Train Epoch: 38 [400/1088 (37%)]	Loss: 1.414032
# Train Epoch: 38 [800/1088 (74%)]	Loss: 0.340940
# Validation set: Average loss: 12.0256, Accuracy: 77/136 (57%)
# Test set: Average loss: 6.4365, Accuracy: 80/136 (59%)
# Train Epoch: 39 [0/1088 (0%)]	Loss: 1.000981
# Train Epoch: 39 [400/1088 (37%)]	Loss: 1.411448
# Train Epoch: 39 [800/1088 (74%)]	Loss: 0.229853
# Validation set: Average loss: 6.8712, Accuracy: 81/136 (60%)
# Test set: Average loss: 4.5709, Accuracy: 85/136 (62%)
# Train Epoch: 40 [0/1088 (0%)]	Loss: 0.095173
# Train Epoch: 40 [400/1088 (37%)]	Loss: 0.761537
# Train Epoch: 40 [800/1088 (74%)]	Loss: 0.032185
# Validation set: Average loss: 12.2851, Accuracy: 78/136 (57%)
# Test set: Average loss: 8.5707, Accuracy: 78/136 (57%)
# Train Epoch: 41 [0/1088 (0%)]	Loss: 0.091997
# Train Epoch: 41 [400/1088 (37%)]	Loss: 0.002598
# Train Epoch: 41 [800/1088 (74%)]	Loss: 1.226764
# Validation set: Average loss: 13.3230, Accuracy: 84/136 (62%)
# Test set: Average loss: 7.4112, Accuracy: 86/136 (63%)
# Train Epoch: 42 [0/1088 (0%)]	Loss: 0.055822
# Train Epoch: 42 [400/1088 (37%)]	Loss: 0.028855
# Train Epoch: 42 [800/1088 (74%)]	Loss: 0.086744
# Validation set: Average loss: 5.6000, Accuracy: 80/136 (59%)
# Test set: Average loss: 3.9150, Accuracy: 81/136 (60%)
# Train Epoch: 43 [0/1088 (0%)]	Loss: 0.471967
# Train Epoch: 43 [400/1088 (37%)]	Loss: 0.519157
# Train Epoch: 43 [800/1088 (74%)]	Loss: 0.544005
# Validation set: Average loss: 9.3066, Accuracy: 84/136 (62%)
# Test set: Average loss: 6.9399, Accuracy: 88/136 (65%)
# Train Epoch: 44 [0/1088 (0%)]	Loss: 0.113568
# Train Epoch: 44 [400/1088 (37%)]	Loss: 0.909795
# Train Epoch: 44 [800/1088 (74%)]	Loss: 0.012971
# Validation set: Average loss: 12.3364, Accuracy: 85/136 (62%)
# Test set: Average loss: 7.8678, Accuracy: 79/136 (58%)
# Train Epoch: 45 [0/1088 (0%)]	Loss: 0.046199
# Train Epoch: 45 [400/1088 (37%)]	Loss: 0.022267
# Train Epoch: 45 [800/1088 (74%)]	Loss: 0.182505
# Validation set: Average loss: 6.6938, Accuracy: 87/136 (64%)
# Test set: Average loss: 4.3256, Accuracy: 88/136 (65%)
# Train Epoch: 46 [0/1088 (0%)]	Loss: 0.184638
# Train Epoch: 46 [400/1088 (37%)]	Loss: 0.832296
# Train Epoch: 46 [800/1088 (74%)]	Loss: 0.344599
# Validation set: Average loss: 6.7587, Accuracy: 82/136 (60%)
# Test set: Average loss: 5.5597, Accuracy: 84/136 (62%)
# Train Epoch: 47 [0/1088 (0%)]	Loss: 1.252676
# Train Epoch: 47 [400/1088 (37%)]	Loss: 0.133376
# Train Epoch: 47 [800/1088 (74%)]	Loss: 0.054760
# Validation set: Average loss: 19.1075, Accuracy: 84/136 (62%)
# Test set: Average loss: 10.9623, Accuracy: 87/136 (64%)
# Train Epoch: 48 [0/1088 (0%)]	Loss: 0.195835
# Train Epoch: 48 [400/1088 (37%)]	Loss: 0.052949
# Train Epoch: 48 [800/1088 (74%)]	Loss: 0.484869
# Validation set: Average loss: 6.8190, Accuracy: 86/136 (63%)
# Test set: Average loss: 5.4998, Accuracy: 81/136 (60%)
# Train Epoch: 49 [0/1088 (0%)]	Loss: 0.715356
# Train Epoch: 49 [400/1088 (37%)]	Loss: 0.089807
# Train Epoch: 49 [800/1088 (74%)]	Loss: 0.621084
# Validation set: Average loss: 4.1096, Accuracy: 91/136 (67%)
# Test set: Average loss: 3.6864, Accuracy: 96/136 (71%)
# Train Epoch: 50 [0/1088 (0%)]	Loss: 0.380159
# Train Epoch: 50 [400/1088 (37%)]	Loss: 0.030867
# Train Epoch: 50 [800/1088 (74%)]	Loss: 0.437390
# Validation set: Average loss: 4.8801, Accuracy: 95/136 (70%)
# Test set: Average loss: 3.8770, Accuracy: 93/136 (68%)
# Train Epoch: 51 [0/1088 (0%)]	Loss: 0.062900
# Train Epoch: 51 [400/1088 (37%)]	Loss: 0.037455
# Train Epoch: 51 [800/1088 (74%)]	Loss: 0.092931
# Validation set: Average loss: 3.1670, Accuracy: 90/136 (66%)
# Test set: Average loss: 3.9013, Accuracy: 89/136 (65%)
# Train Epoch: 52 [0/1088 (0%)]	Loss: 1.217049
# Train Epoch: 52 [400/1088 (37%)]	Loss: 0.486801
# Train Epoch: 52 [800/1088 (74%)]	Loss: 0.003142
# Validation set: Average loss: 16.6487, Accuracy: 70/136 (51%)
# Test set: Average loss: 13.5107, Accuracy: 66/136 (49%)
# Train Epoch: 53 [0/1088 (0%)]	Loss: 0.036662
# Train Epoch: 53 [400/1088 (37%)]	Loss: 0.240070
# Train Epoch: 53 [800/1088 (74%)]	Loss: 0.035278
# Validation set: Average loss: 4.8672, Accuracy: 89/136 (65%)
# Test set: Average loss: 3.3993, Accuracy: 85/136 (62%)
# Train Epoch: 54 [0/1088 (0%)]	Loss: 0.018473
# Train Epoch: 54 [400/1088 (37%)]	Loss: 0.596129
# Train Epoch: 54 [800/1088 (74%)]	Loss: 0.023222
# Validation set: Average loss: 12.3054, Accuracy: 83/136 (61%)
# Test set: Average loss: 7.2658, Accuracy: 94/136 (69%)
# Train Epoch: 55 [0/1088 (0%)]	Loss: 0.024976
# Train Epoch: 55 [400/1088 (37%)]	Loss: 0.316887
# Train Epoch: 55 [800/1088 (74%)]	Loss: 0.827619
# Validation set: Average loss: 7.2184, Accuracy: 91/136 (67%)
# Test set: Average loss: 4.5673, Accuracy: 86/136 (63%)
# Train Epoch: 56 [0/1088 (0%)]	Loss: 0.010249
# Train Epoch: 56 [400/1088 (37%)]	Loss: 0.033448
# Train Epoch: 56 [800/1088 (74%)]	Loss: 0.078575
# Validation set: Average loss: 16.2558, Accuracy: 85/136 (62%)
# Test set: Average loss: 11.2488, Accuracy: 78/136 (57%)
# Train Epoch: 57 [0/1088 (0%)]	Loss: 0.066033
# Train Epoch: 57 [400/1088 (37%)]	Loss: 0.009911
# Train Epoch: 57 [800/1088 (74%)]	Loss: 0.003671
# Validation set: Average loss: 8.3130, Accuracy: 85/136 (62%)
# Test set: Average loss: 6.1686, Accuracy: 88/136 (65%)
# Train Epoch: 58 [0/1088 (0%)]	Loss: 0.657883
# Train Epoch: 58 [400/1088 (37%)]	Loss: 0.068915
# Train Epoch: 58 [800/1088 (74%)]	Loss: 0.002071
# Validation set: Average loss: 15.5373, Accuracy: 78/136 (57%)
# Test set: Average loss: 11.8563, Accuracy: 78/136 (57%)
# Train Epoch: 59 [0/1088 (0%)]	Loss: 0.051065
# Train Epoch: 59 [400/1088 (37%)]	Loss: 0.819258
# Train Epoch: 59 [800/1088 (74%)]	Loss: 0.138539
# Validation set: Average loss: 15.1605, Accuracy: 86/136 (63%)
# Test set: Average loss: 10.8300, Accuracy: 86/136 (63%)
# Train Epoch: 60 [0/1088 (0%)]	Loss: 0.005073
# Train Epoch: 60 [400/1088 (37%)]	Loss: 0.163246
# Train Epoch: 60 [800/1088 (74%)]	Loss: 0.008840
# Validation set: Average loss: 11.4774, Accuracy: 85/136 (62%)
# Test set: Average loss: 7.8530, Accuracy: 78/136 (57%)
# Batch size: 32
# Train Epoch: 1 [0/1088 (0%)]	Loss: 3.087247
# Validation set: Average loss: 3.0872, Accuracy: 13/136 (10%)
# Test set: Average loss: 2.9962, Accuracy: 10/136 (7%)
# Train Epoch: 2 [0/1088 (0%)]	Loss: 2.954463
# Validation set: Average loss: 3.1376, Accuracy: 18/136 (13%)
# Test set: Average loss: 3.3496, Accuracy: 11/136 (8%)
# Train Epoch: 3 [0/1088 (0%)]	Loss: 2.431371
# Validation set: Average loss: 2.5783, Accuracy: 17/136 (12%)
# Test set: Average loss: 2.6606, Accuracy: 27/136 (20%)
# Train Epoch: 4 [0/1088 (0%)]	Loss: 2.191812
# Validation set: Average loss: 2.5365, Accuracy: 34/136 (25%)
# Test set: Average loss: 2.6608, Accuracy: 28/136 (21%)
# Train Epoch: 5 [0/1088 (0%)]	Loss: 2.180706
# Validation set: Average loss: 2.7034, Accuracy: 19/136 (14%)
# Test set: Average loss: 2.6050, Accuracy: 28/136 (21%)
# Train Epoch: 6 [0/1088 (0%)]	Loss: 2.104817
# Validation set: Average loss: 2.3859, Accuracy: 17/136 (12%)
# Test set: Average loss: 2.5813, Accuracy: 22/136 (16%)
# Train Epoch: 7 [0/1088 (0%)]	Loss: 2.289794
# Validation set: Average loss: 2.2522, Accuracy: 35/136 (26%)
# Test set: Average loss: 2.3905, Accuracy: 30/136 (22%)
# Train Epoch: 8 [0/1088 (0%)]	Loss: 1.952815
# Validation set: Average loss: 2.3840, Accuracy: 37/136 (27%)
# Test set: Average loss: 2.5199, Accuracy: 35/136 (26%)
# Train Epoch: 9 [0/1088 (0%)]	Loss: 2.034034
# Validation set: Average loss: 2.2555, Accuracy: 41/136 (30%)
# Test set: Average loss: 2.2324, Accuracy: 46/136 (34%)
# Train Epoch: 10 [0/1088 (0%)]	Loss: 1.826211
# Validation set: Average loss: 2.3166, Accuracy: 42/136 (31%)
# Test set: Average loss: 2.2565, Accuracy: 41/136 (30%)
# Train Epoch: 11 [0/1088 (0%)]	Loss: 2.052460
# Validation set: Average loss: 1.9309, Accuracy: 45/136 (33%)
# Test set: Average loss: 1.9545, Accuracy: 54/136 (40%)
# Train Epoch: 12 [0/1088 (0%)]	Loss: 1.717077
# Validation set: Average loss: 1.8770, Accuracy: 53/136 (39%)
# Test set: Average loss: 1.9935, Accuracy: 47/136 (35%)
# Train Epoch: 13 [0/1088 (0%)]	Loss: 1.399442
# Validation set: Average loss: 1.7804, Accuracy: 62/136 (46%)
# Test set: Average loss: 1.8878, Accuracy: 52/136 (38%)
# Train Epoch: 14 [0/1088 (0%)]	Loss: 1.436535
# Validation set: Average loss: 1.8357, Accuracy: 67/136 (49%)
# Test set: Average loss: 2.1323, Accuracy: 44/136 (32%)
# Train Epoch: 15 [0/1088 (0%)]	Loss: 1.457865
# Validation set: Average loss: 1.5929, Accuracy: 63/136 (46%)
# Test set: Average loss: 1.9469, Accuracy: 51/136 (38%)
# Train Epoch: 16 [0/1088 (0%)]	Loss: 1.183069
# Validation set: Average loss: 1.5044, Accuracy: 75/136 (55%)
# Test set: Average loss: 1.7275, Accuracy: 55/136 (40%)
# Train Epoch: 17 [0/1088 (0%)]	Loss: 1.038971
# Validation set: Average loss: 1.4259, Accuracy: 76/136 (56%)
# Test set: Average loss: 1.7681, Accuracy: 60/136 (44%)
# Train Epoch: 18 [0/1088 (0%)]	Loss: 0.960702
# Validation set: Average loss: 1.6849, Accuracy: 71/136 (52%)
# Test set: Average loss: 2.0816, Accuracy: 48/136 (35%)
# Train Epoch: 19 [0/1088 (0%)]	Loss: 1.156807
# Validation set: Average loss: 1.4746, Accuracy: 69/136 (51%)
# Test set: Average loss: 1.7329, Accuracy: 58/136 (43%)
# Train Epoch: 20 [0/1088 (0%)]	Loss: 1.246167
# Validation set: Average loss: 1.5485, Accuracy: 78/136 (57%)
# Test set: Average loss: 1.8474, Accuracy: 58/136 (43%)
# Train Epoch: 21 [0/1088 (0%)]	Loss: 0.780104
# Validation set: Average loss: 1.5374, Accuracy: 76/136 (56%)
# Test set: Average loss: 1.7774, Accuracy: 67/136 (49%)
# Train Epoch: 22 [0/1088 (0%)]	Loss: 0.933071
# Validation set: Average loss: 1.4057, Accuracy: 72/136 (53%)
# Test set: Average loss: 1.6743, Accuracy: 67/136 (49%)
# Train Epoch: 23 [0/1088 (0%)]	Loss: 1.085302
# Validation set: Average loss: 1.3192, Accuracy: 82/136 (60%)
# Test set: Average loss: 1.6916, Accuracy: 61/136 (45%)
# Train Epoch: 24 [0/1088 (0%)]	Loss: 0.764701
# Validation set: Average loss: 1.5332, Accuracy: 77/136 (57%)
# Test set: Average loss: 1.6926, Accuracy: 66/136 (49%)
# Train Epoch: 25 [0/1088 (0%)]	Loss: 0.786110
# Validation set: Average loss: 1.2675, Accuracy: 80/136 (59%)
# Test set: Average loss: 1.5736, Accuracy: 69/136 (51%)
# Train Epoch: 26 [0/1088 (0%)]	Loss: 0.640978
# Validation set: Average loss: 1.4622, Accuracy: 75/136 (55%)
# Test set: Average loss: 1.6713, Accuracy: 66/136 (49%)
# Train Epoch: 27 [0/1088 (0%)]	Loss: 0.677049
# Validation set: Average loss: 1.4777, Accuracy: 75/136 (55%)
# Test set: Average loss: 1.8913, Accuracy: 62/136 (46%)
# Train Epoch: 28 [0/1088 (0%)]	Loss: 0.973959
# Validation set: Average loss: 1.2895, Accuracy: 85/136 (62%)
# Test set: Average loss: 1.5327, Accuracy: 77/136 (57%)
# Train Epoch: 29 [0/1088 (0%)]	Loss: 0.420700
# Validation set: Average loss: 1.5279, Accuracy: 79/136 (58%)
# Test set: Average loss: 1.9971, Accuracy: 68/136 (50%)
# Train Epoch: 30 [0/1088 (0%)]	Loss: 0.427067
# Validation set: Average loss: 1.3350, Accuracy: 86/136 (63%)
# Test set: Average loss: 1.4343, Accuracy: 79/136 (58%)
# Train Epoch: 31 [0/1088 (0%)]	Loss: 0.334616
# Validation set: Average loss: 1.5055, Accuracy: 86/136 (63%)
# Test set: Average loss: 1.6925, Accuracy: 74/136 (54%)
# Train Epoch: 32 [0/1088 (0%)]	Loss: 0.531555
# Validation set: Average loss: 1.3390, Accuracy: 87/136 (64%)
# Test set: Average loss: 1.5816, Accuracy: 73/136 (54%)
# Train Epoch: 33 [0/1088 (0%)]	Loss: 0.778232
# Validation set: Average loss: 1.2404, Accuracy: 91/136 (67%)
# Test set: Average loss: 1.5501, Accuracy: 77/136 (57%)
# Train Epoch: 34 [0/1088 (0%)]	Loss: 0.487636
# Validation set: Average loss: 1.1624, Accuracy: 89/136 (65%)
# Test set: Average loss: 1.4626, Accuracy: 79/136 (58%)
# Train Epoch: 35 [0/1088 (0%)]	Loss: 0.443175
# Validation set: Average loss: 1.4362, Accuracy: 78/136 (57%)
# Test set: Average loss: 1.6392, Accuracy: 74/136 (54%)
# Train Epoch: 36 [0/1088 (0%)]	Loss: 0.897095
# Validation set: Average loss: 1.2952, Accuracy: 88/136 (65%)
# Test set: Average loss: 1.5761, Accuracy: 77/136 (57%)
# Train Epoch: 37 [0/1088 (0%)]	Loss: 0.444382
# Validation set: Average loss: 1.5498, Accuracy: 78/136 (57%)
# Test set: Average loss: 1.8433, Accuracy: 69/136 (51%)
# Train Epoch: 38 [0/1088 (0%)]	Loss: 0.228966
# Validation set: Average loss: 2.2108, Accuracy: 74/136 (54%)
# Test set: Average loss: 2.1544, Accuracy: 77/136 (57%)
# Train Epoch: 39 [0/1088 (0%)]	Loss: 0.397700
# Validation set: Average loss: 1.3713, Accuracy: 91/136 (67%)
# Test set: Average loss: 1.5340, Accuracy: 79/136 (58%)
# Train Epoch: 40 [0/1088 (0%)]	Loss: 0.181725
# Validation set: Average loss: 1.3583, Accuracy: 86/136 (63%)
# Test set: Average loss: 1.4710, Accuracy: 79/136 (58%)
# Train Epoch: 41 [0/1088 (0%)]	Loss: 0.196936
# Validation set: Average loss: 1.2291, Accuracy: 94/136 (69%)
# Test set: Average loss: 1.5599, Accuracy: 73/136 (54%)
# Train Epoch: 42 [0/1088 (0%)]	Loss: 0.597137
# Validation set: Average loss: 1.4607, Accuracy: 81/136 (60%)
# Test set: Average loss: 1.7237, Accuracy: 72/136 (53%)
# Train Epoch: 43 [0/1088 (0%)]	Loss: 0.160338
# Validation set: Average loss: 1.1286, Accuracy: 94/136 (69%)
# Test set: Average loss: 1.4614, Accuracy: 80/136 (59%)
# Train Epoch: 44 [0/1088 (0%)]	Loss: 0.225645
# Validation set: Average loss: 1.3032, Accuracy: 89/136 (65%)
# Test set: Average loss: 1.5433, Accuracy: 77/136 (57%)
# Train Epoch: 45 [0/1088 (0%)]	Loss: 0.522324
# Validation set: Average loss: 1.3197, Accuracy: 85/136 (62%)
# Test set: Average loss: 1.3882, Accuracy: 83/136 (61%)
# Train Epoch: 46 [0/1088 (0%)]	Loss: 0.099930
# Validation set: Average loss: 1.1065, Accuracy: 92/136 (68%)
# Test set: Average loss: 1.4430, Accuracy: 75/136 (55%)
# Train Epoch: 47 [0/1088 (0%)]	Loss: 0.291030
# Validation set: Average loss: 1.2871, Accuracy: 94/136 (69%)
# Test set: Average loss: 1.4082, Accuracy: 86/136 (63%)
# Train Epoch: 48 [0/1088 (0%)]	Loss: 0.100484
# Validation set: Average loss: 1.1662, Accuracy: 94/136 (69%)
# Test set: Average loss: 1.3439, Accuracy: 79/136 (58%)
# Train Epoch: 49 [0/1088 (0%)]	Loss: 0.311458
# Validation set: Average loss: 1.1754, Accuracy: 93/136 (68%)
# Test set: Average loss: 1.4204, Accuracy: 81/136 (60%)
# Train Epoch: 50 [0/1088 (0%)]	Loss: 0.093095
# Validation set: Average loss: 1.3655, Accuracy: 95/136 (70%)
# Test set: Average loss: 1.5391, Accuracy: 82/136 (60%)
# Train Epoch: 51 [0/1088 (0%)]	Loss: 0.078680
# Validation set: Average loss: 1.2721, Accuracy: 88/136 (65%)
# Test set: Average loss: 1.5570, Accuracy: 79/136 (58%)
# Train Epoch: 52 [0/1088 (0%)]	Loss: 0.064086
# Validation set: Average loss: 1.2889, Accuracy: 96/136 (71%)
# Test set: Average loss: 1.4147, Accuracy: 86/136 (63%)
# Train Epoch: 53 [0/1088 (0%)]	Loss: 0.078859
# Validation set: Average loss: 1.2612, Accuracy: 93/136 (68%)
# Test set: Average loss: 1.5369, Accuracy: 83/136 (61%)
# Train Epoch: 54 [0/1088 (0%)]	Loss: 0.101619
# Validation set: Average loss: 1.1613, Accuracy: 96/136 (71%)
# Test set: Average loss: 1.3497, Accuracy: 83/136 (61%)
# Train Epoch: 55 [0/1088 (0%)]	Loss: 0.032141
# Validation set: Average loss: 1.4120, Accuracy: 89/136 (65%)
# Test set: Average loss: 1.5086, Accuracy: 83/136 (61%)
# Train Epoch: 56 [0/1088 (0%)]	Loss: 0.100056
# Validation set: Average loss: 1.2592, Accuracy: 98/136 (72%)
# Test set: Average loss: 1.5719, Accuracy: 76/136 (56%)
# Train Epoch: 57 [0/1088 (0%)]	Loss: 0.135375
# Validation set: Average loss: 1.3507, Accuracy: 93/136 (68%)
# Test set: Average loss: 1.4222, Accuracy: 81/136 (60%)
# Train Epoch: 58 [0/1088 (0%)]	Loss: 0.196250
# Validation set: Average loss: 1.2482, Accuracy: 94/136 (69%)
# Test set: Average loss: 1.7143, Accuracy: 76/136 (56%)
# Train Epoch: 59 [0/1088 (0%)]	Loss: 0.120891
# Validation set: Average loss: 1.0083, Accuracy: 101/136 (74%)
# Test set: Average loss: 1.3794, Accuracy: 81/136 (60%)
# Train Epoch: 60 [0/1088 (0%)]	Loss: 0.101306
# Validation set: Average loss: 1.0521, Accuracy: 99/136 (73%)
# Test set: Average loss: 1.4561, Accuracy: 79/136 (58%)
# Batch size: 64
# Train Epoch: 1 [0/1088 (0%)]	Loss: 3.027539
# Validation set: Average loss: 2.9250, Accuracy: 8/136 (6%)
# Test set: Average loss: 2.8634, Accuracy: 16/136 (12%)
# Train Epoch: 2 [0/1088 (0%)]	Loss: 2.847915
# Validation set: Average loss: 3.1447, Accuracy: 15/136 (11%)
# Test set: Average loss: 2.8887, Accuracy: 11/136 (8%)
# Train Epoch: 3 [0/1088 (0%)]	Loss: 2.766365
# Validation set: Average loss: 3.7859, Accuracy: 9/136 (7%)
# Test set: Average loss: 3.4592, Accuracy: 17/136 (12%)
# Train Epoch: 4 [0/1088 (0%)]	Loss: 2.658205
# Validation set: Average loss: 3.3495, Accuracy: 19/136 (14%)
# Test set: Average loss: 3.0008, Accuracy: 11/136 (8%)
# Train Epoch: 5 [0/1088 (0%)]	Loss: 2.676641
# Validation set: Average loss: 2.9176, Accuracy: 14/136 (10%)
# Test set: Average loss: 2.7377, Accuracy: 24/136 (18%)
# Train Epoch: 6 [0/1088 (0%)]	Loss: 2.693696
# Validation set: Average loss: 3.1444, Accuracy: 20/136 (15%)
# Test set: Average loss: 2.9997, Accuracy: 16/136 (12%)
# Train Epoch: 7 [0/1088 (0%)]	Loss: 2.432799
# Validation set: Average loss: 2.6317, Accuracy: 20/136 (15%)
# Test set: Average loss: 2.5895, Accuracy: 16/136 (12%)
# Train Epoch: 8 [0/1088 (0%)]	Loss: 2.431447
# Validation set: Average loss: 2.5945, Accuracy: 18/136 (13%)
# Test set: Average loss: 2.5134, Accuracy: 15/136 (11%)
# Train Epoch: 9 [0/1088 (0%)]	Loss: 2.315581
# Validation set: Average loss: 2.6394, Accuracy: 23/136 (17%)
# Test set: Average loss: 2.5918, Accuracy: 21/136 (15%)
# Train Epoch: 10 [0/1088 (0%)]	Loss: 2.377974
# Validation set: Average loss: 2.5818, Accuracy: 26/136 (19%)
# Test set: Average loss: 2.6079, Accuracy: 20/136 (15%)
# Train Epoch: 11 [0/1088 (0%)]	Loss: 2.345506
# Validation set: Average loss: 2.5117, Accuracy: 26/136 (19%)
# Test set: Average loss: 2.4082, Accuracy: 27/136 (20%)
# Train Epoch: 12 [0/1088 (0%)]	Loss: 2.360307
# Validation set: Average loss: 2.3273, Accuracy: 27/136 (20%)
# Test set: Average loss: 2.3185, Accuracy: 25/136 (18%)
# Train Epoch: 13 [0/1088 (0%)]	Loss: 2.281282
# Validation set: Average loss: 2.2984, Accuracy: 30/136 (22%)
# Test set: Average loss: 2.3011, Accuracy: 31/136 (23%)
# Train Epoch: 14 [0/1088 (0%)]	Loss: 1.976917
# Validation set: Average loss: 2.4194, Accuracy: 34/136 (25%)
# Test set: Average loss: 2.3332, Accuracy: 27/136 (20%)
# Train Epoch: 15 [0/1088 (0%)]	Loss: 2.009496
# Validation set: Average loss: 2.3801, Accuracy: 26/136 (19%)
# Test set: Average loss: 2.3078, Accuracy: 31/136 (23%)
# Train Epoch: 16 [0/1088 (0%)]	Loss: 1.870759
# Validation set: Average loss: 2.2588, Accuracy: 36/136 (26%)
# Test set: Average loss: 2.2267, Accuracy: 38/136 (28%)
# Train Epoch: 17 [0/1088 (0%)]	Loss: 1.806539
# Validation set: Average loss: 2.1266, Accuracy: 37/136 (27%)
# Test set: Average loss: 2.1923, Accuracy: 36/136 (26%)
# Train Epoch: 18 [0/1088 (0%)]	Loss: 1.758071
# Validation set: Average loss: 2.1393, Accuracy: 42/136 (31%)
# Test set: Average loss: 2.1545, Accuracy: 48/136 (35%)
# Train Epoch: 19 [0/1088 (0%)]	Loss: 1.860198
# Validation set: Average loss: 2.0657, Accuracy: 43/136 (32%)
# Test set: Average loss: 2.0861, Accuracy: 40/136 (29%)
# Train Epoch: 20 [0/1088 (0%)]	Loss: 1.586592
# Validation set: Average loss: 2.4018, Accuracy: 44/136 (32%)
# Test set: Average loss: 2.3127, Accuracy: 39/136 (29%)
# Train Epoch: 21 [0/1088 (0%)]	Loss: 1.684397
# Validation set: Average loss: 2.0395, Accuracy: 56/136 (41%)
# Test set: Average loss: 2.0663, Accuracy: 46/136 (34%)
# Train Epoch: 22 [0/1088 (0%)]	Loss: 1.391626
# Validation set: Average loss: 1.8661, Accuracy: 56/136 (41%)
# Test set: Average loss: 1.9430, Accuracy: 56/136 (41%)
# Train Epoch: 23 [0/1088 (0%)]	Loss: 1.787425
# Validation set: Average loss: 1.9460, Accuracy: 49/136 (36%)
# Test set: Average loss: 2.0326, Accuracy: 56/136 (41%)
# Train Epoch: 24 [0/1088 (0%)]	Loss: 1.409183
# Validation set: Average loss: 1.9585, Accuracy: 52/136 (38%)
# Test set: Average loss: 2.0578, Accuracy: 57/136 (42%)
# Train Epoch: 25 [0/1088 (0%)]	Loss: 1.334975
# Validation set: Average loss: 1.7883, Accuracy: 52/136 (38%)
# Test set: Average loss: 1.7846, Accuracy: 57/136 (42%)
# Train Epoch: 26 [0/1088 (0%)]	Loss: 1.310678
# Validation set: Average loss: 1.8505, Accuracy: 53/136 (39%)
# Test set: Average loss: 1.9490, Accuracy: 49/136 (36%)
# Train Epoch: 27 [0/1088 (0%)]	Loss: 1.371562
# Validation set: Average loss: 1.7094, Accuracy: 60/136 (44%)
# Test set: Average loss: 1.8023, Accuracy: 55/136 (40%)
# Train Epoch: 28 [0/1088 (0%)]	Loss: 1.293995
# Validation set: Average loss: 1.5831, Accuracy: 65/136 (48%)
# Test set: Average loss: 1.6945, Accuracy: 66/136 (49%)
# Train Epoch: 29 [0/1088 (0%)]	Loss: 1.232885
# Validation set: Average loss: 1.6519, Accuracy: 63/136 (46%)
# Test set: Average loss: 1.8230, Accuracy: 56/136 (41%)
# Train Epoch: 30 [0/1088 (0%)]	Loss: 1.155604
# Validation set: Average loss: 1.5957, Accuracy: 66/136 (49%)
# Test set: Average loss: 1.7328, Accuracy: 60/136 (44%)
# Train Epoch: 31 [0/1088 (0%)]	Loss: 1.018445
# Validation set: Average loss: 1.5991, Accuracy: 72/136 (53%)
# Test set: Average loss: 1.7978, Accuracy: 64/136 (47%)
# Train Epoch: 32 [0/1088 (0%)]	Loss: 1.027720
# Validation set: Average loss: 1.5685, Accuracy: 74/136 (54%)
# Test set: Average loss: 1.7211, Accuracy: 61/136 (45%)
# Train Epoch: 33 [0/1088 (0%)]	Loss: 0.952378
# Validation set: Average loss: 1.5131, Accuracy: 71/136 (52%)
# Test set: Average loss: 1.6744, Accuracy: 65/136 (48%)
# Train Epoch: 34 [0/1088 (0%)]	Loss: 0.744145
# Validation set: Average loss: 1.4808, Accuracy: 71/136 (52%)
# Test set: Average loss: 1.7233, Accuracy: 62/136 (46%)
# Train Epoch: 35 [0/1088 (0%)]	Loss: 1.017479
# Validation set: Average loss: 1.4684, Accuracy: 70/136 (51%)
# Test set: Average loss: 1.6970, Accuracy: 61/136 (45%)
# Train Epoch: 36 [0/1088 (0%)]	Loss: 0.956213
# Validation set: Average loss: 1.4235, Accuracy: 79/136 (58%)
# Test set: Average loss: 1.5576, Accuracy: 75/136 (55%)
# Train Epoch: 37 [0/1088 (0%)]	Loss: 0.866749
# Validation set: Average loss: 1.4257, Accuracy: 76/136 (56%)
# Test set: Average loss: 1.6097, Accuracy: 72/136 (53%)
# Train Epoch: 38 [0/1088 (0%)]	Loss: 0.853374
# Validation set: Average loss: 1.4314, Accuracy: 73/136 (54%)
# Test set: Average loss: 1.5927, Accuracy: 63/136 (46%)
# Train Epoch: 39 [0/1088 (0%)]	Loss: 0.755090
# Validation set: Average loss: 1.3967, Accuracy: 74/136 (54%)
# Test set: Average loss: 1.6272, Accuracy: 71/136 (52%)
# Train Epoch: 40 [0/1088 (0%)]	Loss: 0.968430
# Validation set: Average loss: 1.4580, Accuracy: 72/136 (53%)
# Test set: Average loss: 1.6134, Accuracy: 76/136 (56%)
# Train Epoch: 41 [0/1088 (0%)]	Loss: 0.502125
# Validation set: Average loss: 1.2618, Accuracy: 80/136 (59%)
# Test set: Average loss: 1.5182, Accuracy: 73/136 (54%)
# Train Epoch: 42 [0/1088 (0%)]	Loss: 0.515156
# Validation set: Average loss: 1.2690, Accuracy: 82/136 (60%)
# Test set: Average loss: 1.5120, Accuracy: 65/136 (48%)
# Train Epoch: 43 [0/1088 (0%)]	Loss: 0.694622
# Validation set: Average loss: 1.5044, Accuracy: 73/136 (54%)
# Test set: Average loss: 1.7377, Accuracy: 63/136 (46%)
# Train Epoch: 44 [0/1088 (0%)]	Loss: 0.561778
# Validation set: Average loss: 1.3986, Accuracy: 75/136 (55%)
# Test set: Average loss: 1.5736, Accuracy: 77/136 (57%)
# Train Epoch: 45 [0/1088 (0%)]	Loss: 0.437295
# Validation set: Average loss: 1.4391, Accuracy: 73/136 (54%)
# Test set: Average loss: 1.6508, Accuracy: 71/136 (52%)
# Train Epoch: 46 [0/1088 (0%)]	Loss: 0.525211
# Validation set: Average loss: 1.3673, Accuracy: 82/136 (60%)
# Test set: Average loss: 1.4736, Accuracy: 73/136 (54%)
# Train Epoch: 47 [0/1088 (0%)]	Loss: 0.558320
# Validation set: Average loss: 1.3455, Accuracy: 81/136 (60%)
# Test set: Average loss: 1.5539, Accuracy: 76/136 (56%)
# Train Epoch: 48 [0/1088 (0%)]	Loss: 0.561359
# Validation set: Average loss: 1.3341, Accuracy: 83/136 (61%)
# Test set: Average loss: 1.5059, Accuracy: 73/136 (54%)
# Train Epoch: 49 [0/1088 (0%)]	Loss: 0.377296
# Validation set: Average loss: 1.3423, Accuracy: 79/136 (58%)
# Test set: Average loss: 1.4920, Accuracy: 73/136 (54%)
# Train Epoch: 50 [0/1088 (0%)]	Loss: 0.310860
# Validation set: Average loss: 1.3360, Accuracy: 81/136 (60%)
# Test set: Average loss: 1.4830, Accuracy: 75/136 (55%)
# Train Epoch: 51 [0/1088 (0%)]	Loss: 0.327846
# Validation set: Average loss: 1.2536, Accuracy: 91/136 (67%)
# Test set: Average loss: 1.3650, Accuracy: 85/136 (62%)
# Train Epoch: 52 [0/1088 (0%)]	Loss: 0.252643
# Validation set: Average loss: 1.2186, Accuracy: 82/136 (60%)
# Test set: Average loss: 1.4325, Accuracy: 79/136 (58%)
# Train Epoch: 53 [0/1088 (0%)]	Loss: 0.307337
# Validation set: Average loss: 1.3876, Accuracy: 85/136 (62%)
# Test set: Average loss: 1.4266, Accuracy: 82/136 (60%)
# Train Epoch: 54 [0/1088 (0%)]	Loss: 0.287298
# Validation set: Average loss: 1.2174, Accuracy: 90/136 (66%)
# Test set: Average loss: 1.2918, Accuracy: 84/136 (62%)
# Train Epoch: 55 [0/1088 (0%)]	Loss: 0.350945
# Validation set: Average loss: 1.2551, Accuracy: 84/136 (62%)
# Test set: Average loss: 1.4032, Accuracy: 79/136 (58%)
# Train Epoch: 56 [0/1088 (0%)]	Loss: 0.347488
# Validation set: Average loss: 1.2733, Accuracy: 85/136 (62%)
# Test set: Average loss: 1.3826, Accuracy: 81/136 (60%)
# Train Epoch: 57 [0/1088 (0%)]	Loss: 0.168380
# Validation set: Average loss: 1.2472, Accuracy: 86/136 (63%)
# Test set: Average loss: 1.4903, Accuracy: 78/136 (57%)
# Train Epoch: 58 [0/1088 (0%)]	Loss: 0.269615
# Validation set: Average loss: 1.3020, Accuracy: 91/136 (67%)
# Test set: Average loss: 1.4149, Accuracy: 78/136 (57%)
# Train Epoch: 59 [0/1088 (0%)]	Loss: 0.181751
# Validation set: Average loss: 1.2197, Accuracy: 85/136 (62%)
# Test set: Average loss: 1.4796, Accuracy: 78/136 (57%)
# Train Epoch: 60 [0/1088 (0%)]	Loss: 0.189905
# Validation set: Average loss: 1.3099, Accuracy: 87/136 (64%)
# Test set: Average loss: 1.4219, Accuracy: 84/136 (62%)

# %%
# Plot the training for different batch sizes
plt.figure(figsize=(10, 6))
for i in range(len(batch_sizes)):
    plt.plot(train_losses[i], label='batch size = {}'.format(batch_sizes[i]))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Losses')
plt.legend()

# %%
# Plot the validation for different batch sizes
plt.figure(figsize=(10, 6))
for i in range(len(batch_sizes)):
    plt.plot(valid_losses[i], label='batch size = {}'.format(batch_sizes[i]))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Validation Losses')
plt.legend()

# %%
# Plot the test accuracy for different batch sizes
plt.figure(figsize=(10, 6))
for i in range(len(batch_sizes)):
    plt.plot(test_accs[i], label='batch size = {}'.format(batch_sizes[i]))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Test Accuracies')
plt.legend()

# %%
# !mkdir ResNet50_result

# %%
# Change the train_losses, valid_losses, test_losses, test_accs as different pandas dataframes
train_lossespd = pd.DataFrame({'batch_size_64': train_losses[0]})
valid_lossespd = pd.DataFrame({'batch_size_64': valid_losses[0]})
test_accspd = pd.DataFrame({'batch_size_64': test_accs[0]})

# Save the train_losses, valid_losses, test_losses, test_accs as csv files
train_lossespd.to_csv('./AlexNet_result/train_losses.csv', index=True)
valid_lossespd.to_csv('./AlexNet_result/valid_losses.csv', index=True)
test_accspd.to_csv('./AlexNet_result/test_accs.csv', index=True)

# %%
# Change the train_losses, valid_losses, test_losses, test_accs as different pandas dataframes
train_lossespd = pd.DataFrame({'batch_size_4': train_losses[0], 'batch_size_32': train_losses[1], 'batch_size_64': train_losses[2]})
valid_lossespd = pd.DataFrame({'batch_size_4': valid_losses[0], 'batch_size_32': valid_losses[1], 'batch_size_64': valid_losses[2]})
test_accspd = pd.DataFrame({'batch_size_4': test_accs[0], 'batch_size_32': test_accs[1], 'batch_size_64': test_accs[2]})

# Save the train_losses, valid_losses, test_losses, test_accs as csv files
train_lossespd.to_csv('./ResNet50_result/train_losses.csv', index=True)
valid_lossespd.to_csv('./ResNet50_result/valid_losses.csv', index=True)
test_accspd.to_csv('./ResNet50_result/test_accs.csv', index=True)
