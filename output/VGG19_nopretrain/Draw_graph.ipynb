# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Define the learning rate
lrs = [0.0001, 0.001, 0.01]
# Define the batch size
batch_sizes = [4, 32, 64]

# %%
# read the data with lr = 0.0001
train_losses1 = pd.read_csv('./train_loss' + str(lrs[0]) + '.csv')
valid_losses1 = pd.read_csv('./valid_loss' + str(lrs[0]) + '.csv')
train_accs1 = pd.read_csv('./test_acc' + str(lrs[0]) + '.csv')

# read the data with lr = 0.001
train_losses2 = pd.read_csv('./train_loss' + str(lrs[1]) + '.csv')
valid_losses2 = pd.read_csv('./valid_loss' + str(lrs[1]) + '.csv')
train_accs2 = pd.read_csv('./test_acc' + str(lrs[1]) + '.csv')

# read the data with lr = 0.01
train_losses3 = pd.read_csv('./train_loss' + str(lrs[2]) + '.csv')
valid_losses3 = pd.read_csv('./valid_loss' + str(lrs[2]) + '.csv')
train_accs3 = pd.read_csv('./test_acc' + str(lrs[2]) + '.csv')

# %%
train_losses1
# Out:
#     batch_size_4  batch_size_32  batch_size_64
# 0   2.831936e+00       2.826757       2.830509
# 1   1.928696e+00       2.830092       2.829892
# 2   3.086204e+00       2.834095       2.830476
# 3   2.431067e+00       2.830924       2.830121
# 4   2.885809e+00       2.823036       2.836534
# 5   1.400065e+00       2.835922       2.832972
# 6   2.170632e+00       2.823143       2.831512
# 7   2.325202e+00       2.825510       2.815490
# 8   1.428375e+00       2.833353       2.836589
# 9   1.580138e+00       2.821335       2.825067
# 10  9.113309e-01       2.823414       2.827398
# 11  1.735765e+00       2.816807       2.831876
# 12  3.822613e-01       2.817445       2.813958
# 13  7.072092e-01       2.826664       2.827619
# 14  1.462336e+00       2.803866       2.812224
# 15  3.566574e-01       2.835950       2.829269
# 16  2.603678e-03       2.812467       2.815571
# 17  1.116923e-01       2.784863       2.813179
# 18  6.933382e-01       2.664884       2.835460
# 19  2.339123e-01       2.594789       2.811014
# 20  8.205103e-03       2.719820       2.814479
# 21  1.418064e-02       2.446334       2.824252
# 22  1.851240e-03       2.273654       2.811766
# 23  2.577278e+00       2.160569       2.790838
# 24  4.501831e-04       2.181337       2.804836
# 25  4.953303e-04       2.001971       2.802334
# 26  9.655869e-06       1.728197       2.783931
# 27  7.437952e-05       1.713354       2.793140
# 28  3.963451e-05       1.759017       2.761810
# 29  4.082892e-06       1.596067       2.811901
# 30  1.242735e-05       1.634146       2.755641
# 31  5.990204e-06       1.841264       2.738644
# 32  1.173476e-04       1.910947       2.752570
# 33  9.139958e-04       1.491197       2.738745
# 34  6.249148e-05       1.333593       2.712433
# 35  8.046614e-07       1.518065       2.630012
# 36  2.562994e-06       1.330436       2.692719
# 37  6.258484e-07       1.536954       2.608202
# 38  3.933877e-06       1.260645       2.525746
# 39  2.801412e-06       1.303010       2.430006
# 40  2.768502e-05       1.258784       2.313026
# 41  3.367647e-06       0.754510       2.460358
# 42  3.862083e-05       1.221969       2.245102
# 43  6.556508e-07       0.962732       1.930286
# 44  2.503332e-05       0.890413       2.260147
# 45  3.406175e-05       1.156588       1.944186
# 46  0.000000e+00       0.761201       2.149456
# 47  1.886423e-05       0.380464       1.911288
# 48  8.940696e-08       0.684503       2.052768
# 49  1.549717e-06       0.566367       1.869050
# 50  3.516659e-06       0.427355       1.768295
# 51  7.063051e-06       0.378567       1.930811
# 52  2.980232e-08       0.289165       1.728029
# 53  8.344641e-07       0.405603       1.765436
# 54  6.139203e-06       0.206673       1.614011
# 55  6.895464e-05       0.162392       1.884640
# 56  1.341103e-06       0.381814       1.718698
# 57  2.920618e-06       0.185305       1.801592
# 58  6.258412e-06       0.316252       1.544274
# 59  2.652396e-06       0.268354       1.515962

# %%
# Draw the training loss graph with different learning rates and batch sizes
# 3 figures in line correspond to 3 learning rates
plt.figure(figsize=(12, 7))
plt.subplot(2, 3, 1)
plt.plot(train_losses1['batch_size_4'], label='batch_size_4')
plt.plot(train_losses1['batch_size_32'], label='batch_size_32')
plt.plot(train_losses1['batch_size_64'], label='batch_size_64')
plt.title('Train loss with lr = 0.0001')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim(0, 3.5)
plt.legend()

plt.subplot(2, 3, 2)
plt.plot(train_losses2['batch_size_4'], label='batch_size_4')
plt.plot(train_losses2['batch_size_32'], label='batch_size_32')
plt.plot(train_losses2['batch_size_64'], label='batch_size_64')
plt.title('Train loss with lr = 0.001')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim(0, 3.5)
plt.legend()

plt.subplot(2, 3, 3)
plt.plot(train_losses3['batch_size_4'], label='batch_size_4')
plt.plot(train_losses3['batch_size_32'], label='batch_size_32')
plt.plot(train_losses3['batch_size_64'], label='batch_size_64')
plt.title('Train loss with lr = 0.01')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim(0, 3.5)
plt.legend()

# Draw the test accuracy graph with different learning rates and batch sizes
# 3 figures in line correspond to 3 learning rates
plt.subplot(2, 3, 4)
plt.plot(train_accs1['batch_size_4'], label='batch_size_4')
plt.plot(train_accs1['batch_size_32'], label='batch_size_32')
plt.plot(train_accs1['batch_size_64'], label='batch_size_64')
plt.title('Test accuracy with lr = 0.0001')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim(0, 1)
plt.legend()

plt.subplot(2, 3, 5)
plt.plot(train_accs2['batch_size_4'], label='batch_size_4')
plt.plot(train_accs2['batch_size_32'], label='batch_size_32')
plt.plot(train_accs2['batch_size_64'], label='batch_size_64')
plt.title('Test accuracy with lr = 0.001')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim(0, 1)
plt.legend()

plt.subplot(2, 3, 6)
plt.plot(train_accs3['batch_size_4'], label='batch_size_4')
plt.plot(train_accs3['batch_size_32'], label='batch_size_32')
plt.plot(train_accs3['batch_size_64'], label='batch_size_64')
plt.title('Test accuracy with lr = 0.01')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim(0, 1)
plt.legend()

plt.suptitle('VGG19')
plt.tight_layout()
plt.show()
