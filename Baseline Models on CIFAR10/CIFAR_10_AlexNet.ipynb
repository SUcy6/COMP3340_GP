# %% [markdown]
# ## Split CIFAR-10 into training, validation, and testing sets

# %%
##########################
### SETTINGS
##########################

NUM_CLASSES = 10

# Hyperparameters
random_seed = 1
lr = 0.0001
num_epochs = 60
batch_size = 32

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import PIL

train_transform = transforms.Compose(
    [transforms.Resize(224),
     transforms.RandomHorizontalFlip(p=0.5),
     transforms.RandomAffine(degrees=(-5, 5), translate=(0.1, 0.1), scale=(0.9, 1.1), resample=PIL.Image.BILINEAR),
     transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

test_transform = transforms.Compose(
    [transforms.Resize(224),
     transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=train_transform)
train_set, val_set = torch.utils.data.random_split(dataset, [40000, 10000])

train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=8)
val_loader = torch.utils.data.DataLoader(val_set, batch_size=batch_size, shuffle=False, num_workers=8)

test_set = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=batch_size, shuffle=False, num_workers=8)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:9: DeprecationWarning: BILINEAR is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BILINEAR instead.
#   if __name__ == "__main__":
# /opt/conda/lib/python3.7/site-packages/torchvision/transforms/transforms.py:1421: UserWarning: The parameter 'resample' is deprecated since 0.12 and will be removed in 0.14. Please use 'interpolation' instead.
#   "The parameter 'resample' is deprecated since 0.12 and will be removed in 0.14. "
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# /opt/conda/lib/python3.7/site-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Files already downloaded and verified

# %% [markdown]
# ## Visualize image for each class

# %%
import matplotlib.pyplot as plt
import numpy as np

# visualize training image for each class
sample_images = [dataset.data[np.asarray(dataset.targets) == label][0] for label in range(10)]
# show images
fig, axes = plt.subplots(2, 5, figsize=(12, 6))
i = 0
for row in axes:
  for axis in row:
    axis.set_xticks([])
    axis.set_yticks([])
    axis.set_xlabel(classes[i], fontsize=15)
    axis.imshow(sample_images[i])
    i += 1

# %% [markdown]
# ## Define CNN architecture

# %%
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models
class AlexNet(nn.Module):

    def __init__(self, num_classes):
        super(AlexNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            
            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.avgpool = nn.AdaptiveAvgPool2d((6, 6))
        self.classifier = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(256 * 6 * 6, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            nn.Linear(4096, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = x.view(x.size(0), 256 * 6 * 6)
        logits = self.classifier(x)
        probas = F.softmax(logits, dim=1)
        return logits



net = AlexNet(NUM_CLASSES)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print('Device:', device)
net.to(device)

num_params = sum(p.numel() for p in net.parameters() if p.requires_grad)
print("Number of trainable parameters:", num_params)
# Out:
# Device: cuda:0
# Number of trainable parameters: 57044810

# %%
''' my AlexNet 
# AlexNet model
class AlexNet(nn.Module):
    
    def __init__(self, num_classes: int = 17):
        super(AlexNet, self).__init__()

        self.convolutional = nn.Sequential(
            # first layer
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            # activation function
            nn.ReLU(inplace=True),
            # pooling
            nn.MaxPool2d(kernel_size=3, stride=2),

            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),

            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),

            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),

            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )

        # average pooling layer
        self.avgpool = nn.AdaptiveAvgPool2d((6, 6))

        self.linear = nn.Sequential(
            nn.Dropout(),
            # fully connected layer
            nn.Linear(256 * 6 * 6, 4096),
            nn.ReLU(inplace=True),

            nn.Dropout(),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),

            nn.Linear(4096, NUM_CLASSES) # 2 classes
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:

        x = self.convolutional(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.linear(x)
        return torch.softmax(x, 1)

'''
# User pytorch
# net = torch.hub.load('pytorch/vision:v0.10.0', 'alexnet', pretrained=True)
# Out:
# ' my AlexNet \n# AlexNet model\nclass AlexNet(nn.Module):\n    \n    def __init__(self, num_classes: int = 17):\n        super(AlexNet, self).__init__()\n\n        self.convolutional = nn.Sequential(\n            # first layer\n            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),\n            # activation function\n            nn.ReLU(inplace=True),\n            # pooling\n            nn.MaxPool2d(kernel_size=3, stride=2),\n\n            nn.Conv2d(64, 192, kernel_size=5, padding=2),\n            nn.ReLU(inplace=True),\n            nn.MaxPool2d(kernel_size=3, stride=2),\n\n            nn.Conv2d(192, 384, kernel_size=3, padding=1),\n            nn.ReLU(inplace=True),\n\n            nn.Conv2d(384, 256, kernel_size=3, padding=1),\n            nn.ReLU(inplace=True),\n\n            nn.Conv2d(256, 256, kernel_size=3, padding=1),\n            nn.ReLU(inplace=True),\n            nn.MaxPool2d(kernel_size=3, stride=2),\n        )\n\n        # average pooling layer\n        self.avgpool = nn.AdaptiveAvgPool2d((6, 6))\n\n        self.linear = nn.Sequential(\n            nn.Dropout(),\n            # fully connected layer\n            nn.Linear(256 * 6 * 6, 4096),\n            nn.ReLU(inplace=True),\n\n            nn.Dropout(),\n            nn.Linear(4096, 4096),\n            nn.ReLU(inplace=True),\n\n            nn.Linear(4096, NUM_CLASSES) # 2 classes\n        )\n\n    def forward(self, x: torch.Tensor) -> torch.Tensor:\n\n        x = self.convolutional(x)\n        x = self.avgpool(x)\n        x = torch.flatten(x, 1)\n        x = self.linear(x)\n        return torch.softmax(x, 1)\n\n'

# %% [markdown]
# ## Training

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.0001, betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10, verbose=True, min_lr=0)

loss_hist, acc_hist = [], []
loss_hist_val, acc_hist_val = [], []

for epoch in range(num_epochs):
  running_loss = 0.0
  correct = 0
  for data in train_loader:
    batch, labels = data
    batch, labels = batch.to(device), labels.to(device)

    optimizer.zero_grad()
    outputs = net(batch)
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()

    # compute training statistics
    _, predicted = torch.max(outputs, 1)
    correct += (predicted == labels).sum().item()
    running_loss += loss.item()

  avg_loss = running_loss / len(train_set)
  avg_acc = correct / len(train_set)
  loss_hist.append(avg_loss)
  acc_hist.append(avg_acc)

  # validation statistics
  net.eval()
  with torch.no_grad():
    loss_val = 0.0
    correct_val = 0
    for data in val_loader:
      batch, labels = data
      batch, labels = batch.to(device), labels.to(device)
      outputs = net(batch)
      loss = criterion(outputs, labels)
      _, predicted = torch.max(outputs, 1)
      correct_val += (predicted == labels).sum().item()
      loss_val += loss.item()
    avg_loss_val = loss_val / len(val_set)
    avg_acc_val = correct_val / len(val_set)
    loss_hist_val.append(avg_loss_val)
    acc_hist_val.append(avg_acc_val)
  net.train()

  scheduler.step(avg_loss_val)
  print('[epoch %d] loss: %.5f accuracy: %.4f val loss: %.5f val accuracy: %.4f' % (epoch + 1, avg_loss, avg_acc, avg_loss_val, avg_acc_val))
# Out:
# [epoch 1] loss: 0.05119 accuracy: 0.3896 val loss: 0.04040 val accuracy: 0.5324
# [epoch 2] loss: 0.03758 accuracy: 0.5665 val loss: 0.03251 val accuracy: 0.6309
# [epoch 3] loss: 0.03137 accuracy: 0.6452 val loss: 0.03113 val accuracy: 0.6545
# [epoch 4] loss: 0.02677 accuracy: 0.6990 val loss: 0.02475 val accuracy: 0.7239
# [epoch 5] loss: 0.02393 accuracy: 0.7321 val loss: 0.02192 val accuracy: 0.7571
# [epoch 6] loss: 0.02152 accuracy: 0.7595 val loss: 0.02137 val accuracy: 0.7680
# [epoch 7] loss: 0.01978 accuracy: 0.7804 val loss: 0.01899 val accuracy: 0.7922
# [epoch 8] loss: 0.01841 accuracy: 0.7949 val loss: 0.01786 val accuracy: 0.8029
# [epoch 9] loss: 0.01695 accuracy: 0.8110 val loss: 0.01884 val accuracy: 0.7952
# [epoch 10] loss: 0.01590 accuracy: 0.8233 val loss: 0.01723 val accuracy: 0.8106
# [epoch 11] loss: 0.01480 accuracy: 0.8352 val loss: 0.01656 val accuracy: 0.8205
# [epoch 12] loss: 0.01383 accuracy: 0.8447 val loss: 0.01563 val accuracy: 0.8284
# [epoch 13] loss: 0.01305 accuracy: 0.8542 val loss: 0.01677 val accuracy: 0.8202
# [epoch 14] loss: 0.01232 accuracy: 0.8636 val loss: 0.01512 val accuracy: 0.8371
# [epoch 15] loss: 0.01166 accuracy: 0.8711 val loss: 0.01520 val accuracy: 0.8331
# [epoch 16] loss: 0.01102 accuracy: 0.8769 val loss: 0.01517 val accuracy: 0.8413
# [epoch 17] loss: 0.01070 accuracy: 0.8806 val loss: 0.01523 val accuracy: 0.8395
# [epoch 18] loss: 0.00996 accuracy: 0.8886 val loss: 0.01441 val accuracy: 0.8494
# [epoch 19] loss: 0.00954 accuracy: 0.8921 val loss: 0.01506 val accuracy: 0.8465
# [epoch 20] loss: 0.00907 accuracy: 0.8983 val loss: 0.01488 val accuracy: 0.8484
# [epoch 21] loss: 0.00865 accuracy: 0.9015 val loss: 0.01519 val accuracy: 0.8458
# [epoch 22] loss: 0.00843 accuracy: 0.9051 val loss: 0.01424 val accuracy: 0.8538
# [epoch 23] loss: 0.00783 accuracy: 0.9116 val loss: 0.01535 val accuracy: 0.8542
# [epoch 24] loss: 0.00754 accuracy: 0.9148 val loss: 0.01488 val accuracy: 0.8524
# [epoch 25] loss: 0.00717 accuracy: 0.9183 val loss: 0.01471 val accuracy: 0.8635
# [epoch 26] loss: 0.00688 accuracy: 0.9233 val loss: 0.01427 val accuracy: 0.8579
# [epoch 27] loss: 0.00674 accuracy: 0.9264 val loss: 0.01606 val accuracy: 0.8517
# [epoch 28] loss: 0.00657 accuracy: 0.9255 val loss: 0.01407 val accuracy: 0.8625
# [epoch 29] loss: 0.00630 accuracy: 0.9298 val loss: 0.01637 val accuracy: 0.8638
# [epoch 30] loss: 0.00604 accuracy: 0.9314 val loss: 0.01551 val accuracy: 0.8554
# [epoch 31] loss: 0.00592 accuracy: 0.9346 val loss: 0.01502 val accuracy: 0.8610
# [epoch 32] loss: 0.00556 accuracy: 0.9378 val loss: 0.01480 val accuracy: 0.8577
# [epoch 33] loss: 0.00542 accuracy: 0.9407 val loss: 0.01464 val accuracy: 0.8642
# [epoch 34] loss: 0.00543 accuracy: 0.9368 val loss: 0.01494 val accuracy: 0.8578
# [epoch 35] loss: 0.00506 accuracy: 0.9432 val loss: 0.01580 val accuracy: 0.8574
# [epoch 36] loss: 0.00485 accuracy: 0.9459 val loss: 0.01542 val accuracy: 0.8560
# [epoch 37] loss: 0.00484 accuracy: 0.9464 val loss: 0.01597 val accuracy: 0.8582
# [epoch 38] loss: 0.00477 accuracy: 0.9473 val loss: 0.01554 val accuracy: 0.8643
# Epoch 00039: reducing learning rate of group 0 to 1.0000e-05.
# [epoch 39] loss: 0.00452 accuracy: 0.9491 val loss: 0.01599 val accuracy: 0.8592
# [epoch 40] loss: 0.00259 accuracy: 0.9708 val loss: 0.01472 val accuracy: 0.8789
# [epoch 41] loss: 0.00208 accuracy: 0.9771 val loss: 0.01522 val accuracy: 0.8834
# [epoch 42] loss: 0.00169 accuracy: 0.9808 val loss: 0.01597 val accuracy: 0.8834
# [epoch 43] loss: 0.00158 accuracy: 0.9822 val loss: 0.01661 val accuracy: 0.8834
# [epoch 44] loss: 0.00159 accuracy: 0.9819 val loss: 0.01596 val accuracy: 0.8829
# [epoch 45] loss: 0.00137 accuracy: 0.9853 val loss: 0.01650 val accuracy: 0.8815
# [epoch 46] loss: 0.00139 accuracy: 0.9849 val loss: 0.01705 val accuracy: 0.8835
# [epoch 47] loss: 0.00129 accuracy: 0.9856 val loss: 0.01704 val accuracy: 0.8839
# [epoch 48] loss: 0.00132 accuracy: 0.9856 val loss: 0.01691 val accuracy: 0.8841
# [epoch 49] loss: 0.00120 accuracy: 0.9863 val loss: 0.01720 val accuracy: 0.8851
# Epoch 00050: reducing learning rate of group 0 to 1.0000e-06.
# [epoch 50] loss: 0.00120 accuracy: 0.9865 val loss: 0.01711 val accuracy: 0.8843
# [epoch 51] loss: 0.00109 accuracy: 0.9882 val loss: 0.01786 val accuracy: 0.8862
# [epoch 52] loss: 0.00097 accuracy: 0.9899 val loss: 0.01711 val accuracy: 0.8856
# [epoch 53] loss: 0.00100 accuracy: 0.9887 val loss: 0.01782 val accuracy: 0.8846
# [epoch 54] loss: 0.00094 accuracy: 0.9896 val loss: 0.01825 val accuracy: 0.8826
# [epoch 55] loss: 0.00096 accuracy: 0.9896 val loss: 0.01777 val accuracy: 0.8819
# [epoch 56] loss: 0.00094 accuracy: 0.9895 val loss: 0.01870 val accuracy: 0.8812
# [epoch 57] loss: 0.00097 accuracy: 0.9895 val loss: 0.01808 val accuracy: 0.8844
# [epoch 58] loss: 0.00095 accuracy: 0.9895 val loss: 0.01738 val accuracy: 0.8883
# [epoch 59] loss: 0.00095 accuracy: 0.9899 val loss: 0.01773 val accuracy: 0.8853
# [epoch 60] loss: 0.00087 accuracy: 0.9905 val loss: 0.01731 val accuracy: 0.8869

# %% [markdown]
# ## Plotting training statistics

# %%
import matplotlib.pyplot as plt

legend = ['Train', 'Validation']
plt.plot(loss_hist)
plt.plot(loss_hist_val)
plt.title('VGG19 Model Loss on CIFAR-10')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(legend, loc='upper left')
plt.show()

legend = ['Train', 'Validation']
plt.plot(acc_hist)
plt.plot(acc_hist_val)
plt.title('VGG19 Model Accuracy on CIFAR-10')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(legend, loc='upper left')
plt.show()

# %% [markdown]
# ## Save the trained model

# %%
from google.colab import files

torch.save(net.state_dict(), 'checkpoint.pth')
# download checkpoint file
files.download('checkpoint.pth')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_24/460803925.py in <module>
# ----> 1 from google.colab import files
#       2
#       3 torch.save(net.state_dict(), 'checkpoint.pth')
#       4 # download checkpoint file
#       5 files.download('checkpoint.pth')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
net.load_state_dict(torch.load('checkpoint.pth'))

# %% [markdown]
# ## Testing

# %%
pred_vec = []
correct = 0
net.eval()
with torch.no_grad():
    for data in test_loader:
        batch, labels = data
        batch, labels = batch.to(device), labels.to(device)
        outputs = net(batch)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        pred_vec.append(predicted)
    pred_vec = torch.cat(pred_vec)

print('Accuracy on the 10000 test images: %.2f %%' % (100 * correct / len(test_set)))
# Out:
# Accuracy on the 10000 test images: 88.96 %

# %% [markdown]
# ## Visualize wrongly classified image for each class

# %%
import numpy as np

# visualize wrongly classified image for each class
pred_vec = pred_vec.cpu().numpy()
ground_truths = np.asarray(test_set.targets)
incorrect_mask = pred_vec != ground_truths
incorrect_images = [test_set.data[(ground_truths == label) & incorrect_mask][0] for label in range(10)]
pred_results = [pred_vec[(ground_truths == label) & incorrect_mask][0] for label in range(10)]

# show images
fig, axes = plt.subplots(2, 5, figsize=(12, 6))
i = 0
for row in axes:
  for axis in row:
    axis.set_xticks([])
    axis.set_yticks([])
    axis.set_xlabel("Predicted: %s" % classes[pred_results[i]], fontsize=14)
    axis.imshow(incorrect_images[i])
    i += 1
